# %% [markdown]
# # Export All Techniques to CSV

# %% [markdown]
# ## Import Libraries

# %%
from attackcti import attack_client
import pandas
import json

# %% [markdown]
# ## Initialize Attack client

# %%
lift = attack_client()

# %% [markdown]
# ## Get All Techniques STIX Format

# %%
all_techniques = lift.get_techniques()
len(all_techniques)
# Out:
# 858

# %% [markdown]
# ## Export CSV File

# %%
techniques = []
for t in all_techniques:
    techniques.append(json.loads(t.serialize()))
df = pandas.json_normalize(techniques)

# %%
df.head()
# Out:
#              type spec_version  \
# 0  attack-pattern          2.1
# 1  attack-pattern          2.1
# 2  attack-pattern          2.1
# 3  attack-pattern          2.1
# 4  attack-pattern          2.1
#
#                                                   id  \
# 0  attack-pattern--0af0ca99-357d-4ba1-805f-674fdf...
# 1  attack-pattern--09312b1a-c3c6-4b45-9844-3ccc78...
# 2  attack-pattern--0979abf9-4e26-43ec-9b6e-54efc4...
# 3  attack-pattern--09a60ea3-a8d1-4ae5-976e-578324...
# 4  attack-pattern--09b008a9-b4eb-462a-a751-a0eb58...
#
#                                    created_by_ref                   created  \
# 0  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2020-02-20T22:10:20.484Z
# 1  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2020-10-02T16:39:33.966Z
# 2  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2020-10-02T16:58:58.738Z
# 3  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2020-02-11T18:58:11.791Z
# 4  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2024-03-29T16:59:10.374Z
#
#                    modified                            name  \
# 0  2024-10-15T16:32:05.064Z             Disk Structure Wipe
# 1  2024-10-03T19:35:07.269Z  Gather Victim Host Information
# 2  2022-04-25T14:00:00.188Z            Digital Certificates
# 3  2023-10-01T14:01:12.167Z                      Keylogging
# 4  2024-04-15T23:42:39.831Z            File/Path Exclusions
#
#                                          description  \
# 0  Adversaries may corrupt or wipe the disk data ...
# 1  Adversaries may gather information about the v...
# 2  Adversaries may search public digital certific...
# 3  Adversaries may log user keystrokes to interce...
# 4  Adversaries may attempt to hide their file-bas...
#
#                                    kill_chain_phases  \
# 0  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 1  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 2  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 3  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 4  [{'kill_chain_name': 'mitre-attack', 'phase_na...
#
#                                  external_references  ...  \
# 0  [{'source_name': 'mitre-attack', 'url': 'https...  ...
# 1  [{'source_name': 'mitre-attack', 'url': 'https...  ...
# 2  [{'source_name': 'mitre-attack', 'url': 'https...  ...
# 3  [{'source_name': 'mitre-attack', 'url': 'https...  ...
# 4  [{'source_name': 'mitre-attack', 'url': 'https...  ...
#
#                           x_mitre_modified_by_ref  \
# 0  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 4  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                   x_mitre_platforms x_mitre_version x_mitre_defense_bypassed  \
# 0  [Linux, macOS, Windows, Network]             1.1                      NaN
# 1                             [PRE]             1.2                      NaN
# 2                             [PRE]             1.0                      NaN
# 3  [Windows, macOS, Linux, Network]             1.2                      NaN
# 4           [Linux, macOS, Windows]             1.0                      NaN
#
#   x_mitre_remote_support x_mitre_permissions_required  \
# 0                    NaN                          NaN
# 1                    NaN                          NaN
# 2                    NaN                          NaN
# 3                    NaN                          NaN
# 4                    NaN                          NaN
#
#   x_mitre_system_requirements x_mitre_effective_permissions  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#    x_mitre_network_requirements x_mitre_tactic_type
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2                           NaN                 NaN
# 3                           NaN                 NaN
# 4                           NaN                 NaN
#
# [5 rows x 29 columns]

# %%
df.to_csv('all_techniques_stix.csv', index=False)

# %% [markdown]
# ## Get All Techniques Non-STIX Format

# %%
all_techniques = lift.get_techniques(stix_format=False)
len(all_techniques)
# Out:
# 858

# %%
df = pandas.json_normalize(all_techniques)

# %%
df.head()
# Out:
#              type                                                 id  \
# 0  attack-pattern  attack-pattern--0af0ca99-357d-4ba1-805f-674fdf...
# 1  attack-pattern  attack-pattern--09312b1a-c3c6-4b45-9844-3ccc78...
# 2  attack-pattern  attack-pattern--0979abf9-4e26-43ec-9b6e-54efc4...
# 3  attack-pattern  attack-pattern--09a60ea3-a8d1-4ae5-976e-578324...
# 4  attack-pattern  attack-pattern--09b008a9-b4eb-462a-a751-a0eb58...
#
#                                              url               matrix  \
# 0  https://attack.mitre.org/techniques/T1561/002  [enterprise-attack]
# 1      https://attack.mitre.org/techniques/T1592  [enterprise-attack]
# 2  https://attack.mitre.org/techniques/T1596/003  [enterprise-attack]
# 3  https://attack.mitre.org/techniques/T1056/001  [enterprise-attack]
# 4  https://attack.mitre.org/techniques/T1564/012  [enterprise-attack]
#
#                     created                  modified  \
# 0  2020-02-20T22:10:20.484Z  2024-10-15T16:32:05.064Z
# 1  2020-10-02T16:39:33.966Z  2024-10-03T19:35:07.269Z
# 2  2020-10-02T16:58:58.738Z  2022-04-25T14:00:00.188Z
# 3  2020-02-11T18:58:11.791Z  2023-10-01T14:01:12.167Z
# 4  2024-03-29T16:59:10.374Z  2024-04-15T23:42:39.831Z
#
#                                    created_by_ref  \
# 0  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 4  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                   modified_by_ref  \
# 0  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 4  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/techniques/...
# 1  [{'url': 'https://attack.mitre.org/techniques/...
# 2  [{'url': 'https://attack.mitre.org/techniques/...
# 3  [{'url': 'https://attack.mitre.org/techniques/...
# 4  [{'url': 'https://attack.mitre.org/techniques/...
#
#                                  object_marking_refs  ... defense_bypassed  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  ...             None
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  ...             None
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  ...             None
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  ...             None
# 4  [marking-definition--fa42a846-8d90-4e51-bc29-7...  ...             None
#
#   permissions_required effective_permissions system_requirements  \
# 0                 None                  None                None
# 1                 None                  None                None
# 2                 None                  None                None
# 3                 None                  None                None
# 4                 None                  None                None
#
#   network_requirements remote_support                 contributors  \
# 0                 None           None   [Austin Clark, @c2defense]
# 1                 None           None  [Sam Seabrook, Duke Energy]
# 2                 None           None                         None
# 3                 None           None                     [TruKno]
# 4                 None           None                         None
#
#   tactic_type     impact_type is_subtechnique
# 0        None  [Availability]            True
# 1        None            None           False
# 2        None            None            True
# 3        None            None            True
# 4        None            None            True
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Export CSV File

# %%
df.to_csv('all_techniques_non_stix.csv', index=False)

# %% [markdown]
# # **MITRE ATT&CK API BASICS**: Python Client
# ------------------

# %% [markdown]
# ## Import ATTACK API Client

# %%
from attackcti import attack_client

# %% [markdown]
# ## Import Extra Libraries

# %%
from pandas import *
from pandas.io.json import json_normalize
import json

# %%
pandas.__version__
# Out:
# '0.24.1'

# %% [markdown]
# ## Initialize ATT&CK Client Variable

# %%
lift = attack_client()

# %% [markdown]
# ## **Collect (Enterprise ATT&CK, Pre-ATT&CK & Mobile ATT&CK)**
# * I usually collect all the stix object types available from all the ATT&CK Matrices first when I want to analyze ATT&CK's data.
# * In this section, we will collect everything from Enterprise ATT&CK, PRE-ATT&CK and Mobile ATT&CK via three functions that query ATT&CK content available in STIX™ 2.0 format via its own public TAXII™ 2.0 server:
#   * get_all_enterprise()
#   * get_all_pre()
#   * get_all_mobile()

# %% [markdown]
# **Collect ALL Enterprise ATT&CK (TAXII)**

# %%
# %time all_enterprise = lift.get_all_enterprise()
# Out:
# CPU times: user 2.38 s, sys: 163 ms, total: 2.54 s
# Wall time: 19.2 s

# %% [markdown]
# **Collect ALL PRE-ATT&CK (TAXII)**

# %%
# %time all_pre = lift.get_all_pre()
# Out:
# CPU times: user 156 ms, sys: 14.9 ms, total: 171 ms
# Wall time: 1.66 s

# %% [markdown]
# **Collect ALL Mobile ATT&CK (TAXII)**

# %%
# %time all_mobile = lift.get_all_mobile()
# Out:
# CPU times: user 246 ms, sys: 20.7 ms, total: 267 ms
# Wall time: 2.41 s

# %% [markdown]
# ## **Collect ALL (It runs All 3 previous functions and collects all the results)**

# %% [markdown]
# The **get_all_stix_objects()** function returns a dictionary with all the stix object types from all matrices:
# * techniques
# * mitigations
# * groups
# * malware
# * tools
# * relationships

# %%
# %time all_attack = lift.get_all_stix_objects()
# Out:
# CPU times: user 32 s, sys: 401 ms, total: 32.4 s
# Wall time: 59.3 s

# %%
type(all_attack)
# Out:
# dict

# %% [markdown]
# ### Get All Techniques from ATT&CK Results (Locally - STIX format)
# * The results of this function shows every single technique across the whole ATT&CK framework without their mitigations information

# %%
print("Number of Techniques in ATT&CK")
print(len(all_attack['techniques']))
# Out:
# Number of Techniques in ATT&CK
# 500

# %% [markdown]
# * By default, the data returned by the available functions in the attackcti library is of type **stix2**
# * However, if you want to interact with libraries such as **Pandas**, it needs to be of type **dict**

# %%
techniques = []
for t in all_attack['techniques']:
    techniques.append(json.loads(t.serialize()))
df = json_normalize(techniques)
df.reindex(['created','name', 'x_mitre_data_sources', 'x_mitre_platforms'], axis=1)[0:5]
# Out:
#                     created                            name  \
# 0  2019-04-25T20:53:07.719Z          Compile After Delivery
# 1  2019-04-23T15:34:30.008Z                 Systemd Service
# 2  2019-04-18T11:00:55.862Z      Endpoint Denial of Service
# 3  2019-04-17T22:22:24.505Z  Virtualization/Sandbox Evasion
# 4  2019-04-17T20:23:15.105Z       Network Denial of Service
#
#                                 x_mitre_data_sources        x_mitre_platforms
# 0  [Process command-line parameters, Process moni...  [Linux, macOS, Windows]
# 1  [Process command-line parameters, Process moni...                  [Linux]
# 2  [SSL/TLS inspection, Web logs, Web application...  [Linux, macOS, Windows]
# 3  [Process monitoring, Process command-line para...                [Windows]
# 4  [Sensor health and status, Network protocol an...  [Linux, macOS, Windows]

# %% [markdown]
# **Showing the schema of Techniques**

# %% [markdown]
# This schema covers techniques from Enterprise, PRE and Mobile ATT&CK

# %%
list(df)
# Out:
# ['created',
#  'created_by_ref',
#  'description',
#  'external_references',
#  'id',
#  'kill_chain_phases',
#  'modified',
#  'name',
#  'object_marking_refs',
#  'revoked',
#  'type',
#  'x_mitre_contributors',
#  'x_mitre_data_sources',
#  'x_mitre_defense_bypassed',
#  'x_mitre_deprecated',
#  'x_mitre_detectable_by_common_defenses',
#  'x_mitre_detectable_by_common_defenses_explanation',
#  'x_mitre_detection',
#  'x_mitre_difficulty_for_adversary',
#  'x_mitre_difficulty_for_adversary_explanation',
#  'x_mitre_effective_permissions',
#  'x_mitre_impact_type',
#  'x_mitre_network_requirements',
#  'x_mitre_old_attack_id',
#  'x_mitre_permissions_required',
#  'x_mitre_platforms',
#  'x_mitre_remote_support',
#  'x_mitre_system_requirements',
#  'x_mitre_tactic_type',
#  'x_mitre_version']

# %% [markdown]
# **Showing one technique example**

# %%
techniques[0]
# Out:
# {'external_references': [{'external_id': 'T1500',
#    'source_name': 'mitre-attack',
#    'url': 'https://attack.mitre.org/techniques/T1500'},
#   {'url': 'https://www.clearskysec.com/wp-content/uploads/2018/11/MuddyWater-Operations-in-Lebanon-and-Oman.pdf',
#    'source_name': 'ClearSky MuddyWater Nov 2018',
#    'description': 'ClearSky Cyber Security. (2018, November). MuddyWater Operations in Lebanon and Oman: Using an Israeli compromised domain for a two-stage campaign. Retrieved November 29, 2018.'},
#   {'url': 'https://blog.trendmicro.com/trendlabs-security-intelligence/windows-app-runs-on-mac-downloads-info-stealer-and-adware/',
#    'source_name': 'TrendMicro WindowsAppMac',
#    'description': 'Trend Micro. (2019, February 11). Windows App Runs on Mac, Downloads Info Stealer and Adware. Retrieved April 25, 2019.'}],
#  'object_marking_refs': ['marking-definition--fa42a846-8d90-4e51-bc29-71d5b4802168'],
#  'type': 'attack-pattern',
#  'modified': '2019-04-29T21:13:49.686Z',
#  'created_by_ref': 'identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5',
#  'kill_chain_phases': [{'phase_name': 'defense-evasion',
#    'kill_chain_name': 'mitre-attack'}],
#  'id': 'attack-pattern--cf7b3a06-8b42-4c33-bbe9-012120027925',
#  'name': 'Compile After Delivery',
#  'created': '2019-04-25T20:53:07.719Z',
#  'description': 'Adversaries may attempt to make payloads difficult to discover and analyze by delivering files to victims as uncompiled code. Similar to [Obfuscated Files or Information](https://attack.mitre.org/techniques/T1027), text-based source code files may subvert analysis and scrutiny from protections targeting executables/binaries. These payloads will need to be compiled before execution; typically via native utilities such as csc.exe or GCC/MinGW.(Citation: ClearSky MuddyWater Nov 2018)\n\nSource code payloads may also be encrypted, encoded, and/or embedded within other files, such as those delivered as a [Spearphishing Attachment](https://attack.mitre.org/techniques/T1193). Payloads may also be delivered in formats unrecognizable and inherently benign to the native OS (ex: EXEs on macOS/Linux) before later being (re)compiled into a proper executable binary with a bundled compiler and execution framework.(Citation: TrendMicro WindowsAppMac)\n',
#  'x_mitre_contributors': ['Ye Yint Min Thu Htut, Offensive Security Team, DBS Bank',
#   'Praetorian'],
#  'x_mitre_permissions_required': ['User'],
#  'x_mitre_data_sources': ['Process command-line parameters',
#   'Process monitoring',
#   'File monitoring'],
#  'x_mitre_detection': 'Monitor the execution file paths and command-line arguments for common compilers, such as csc.exe and GCC/MinGW, and correlate with other suspicious behavior to reduce false positives from normal user and administrator behavior. The compilation of payloads may also generate file creation and/or file write events. Look for non-native binary formats and cross-platform compiler and execution frameworks like Mono and determine if they have a legitimate purpose on the system.(Citation: TrendMicro WindowsAppMac) Typically these should only be used in specific and limited cases, like for software development.',
#  'x_mitre_platforms': ['Linux', 'macOS', 'Windows'],
#  'x_mitre_version': '1.0',
#  'x_mitre_system_requirements': ['Compiler software (either native to the system or delivered by the adversary)'],
#  'x_mitre_defense_bypassed': ['Static File Analysis',
#   'Binary Analysis',
#   'Anti-virus',
#   'Host intrusion prevention systems',
#   'Signature-based detection']}

# %% [markdown]
# ### Get All Mitigations from ATT&CK Results (Locally)

# %%
print("Number of Mitigations in ATT&CK")
print(len(all_attack['mitigations']))
# Out:
# Number of Mitigations in ATT&CK
# 255

# %% [markdown]
# * Remember, we need to transform our results to dictionaries to be able to use them as pandas dataframes

# %%
mitigations = []
for t in all_attack['mitigations']:
    mitigations.append(json.loads(t.serialize()))
df = json_normalize(mitigations)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-26T19:30:33.607Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-25T20:53:07.814Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-24T17:03:39.689Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-24T17:02:25.107Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  Prevent adversary access to privileged account...
# 1  This type of technique cannot be easily mitiga...
# 2  Identify critical business and system processe...
# 3  Identify critical business and system processe...
#
#                                  external_references  \
# 0  [{'external_id': 'T1495', 'source_name': 'mitr...
# 1  [{'external_id': 'T1502', 'source_name': 'mitr...
# 2  [{'external_id': 'T1493', 'source_name': 'mitr...
# 3  [{'external_id': 'T1492', 'source_name': 'mitr...
#
#                                                   id  \
# 0  course-of-action--70886857-0f19-4caa-b081-5483...
# 1  course-of-action--ae56a49d-5281-45c5-ab95-70a1...
# 2  course-of-action--245075bc-f992-4d89-af8c-834c...
# 3  course-of-action--e9362d25-4427-446b-99e8-b8f0...
#
#                    modified                                      name  \
# 0  2019-04-26T19:41:45.126Z            Firmware Corruption Mitigation
# 1  2019-04-26T14:19:09.167Z         Compile After Delivery Mitigation
# 2  2019-04-26T18:48:27.528Z  Transmitted Data Manipulation Mitigation
# 3  2019-04-26T18:57:01.963Z       Stored Data Manipulation Mitigation
#
#                                  object_marking_refs              type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
#
#   x_mitre_old_attack_id x_mitre_version
# 0                   NaN             1.0
# 1                   NaN             1.0
# 2                   NaN             1.0
# 3                   NaN             1.0

# %%
list(df)
# Out:
# ['created',
#  'created_by_ref',
#  'description',
#  'external_references',
#  'id',
#  'modified',
#  'name',
#  'object_marking_refs',
#  'type',
#  'x_mitre_old_attack_id',
#  'x_mitre_version']

# %% [markdown]
# ### Get All Groups from ATT&CK Results (Locally)

# %%
print("Number of Groups in ATT&CK")
print(len(all_attack['groups']))
# Out:
# Number of Groups in ATT&CK
# 88

# %% [markdown]
# * Once again, we need to transform our results to dictionaries to be able to use them as pandas dataframes

# %%
groups = []
for t in all_attack['groups']:
    groups.append(json.loads(t.serialize()))
df = json_normalize(groups)
df[0:4]
# Out:
#                   aliases                   created  \
# 0  [TEMP.Veles, XENOTIME]  2019-04-16T15:14:38.533Z
# 1         [APT39, Chafer]  2019-02-19T16:01:38.585Z
# 2         [Stolen Pencil]  2019-02-05T17:56:55.233Z
# 3                  [FIN4]  2019-01-31T02:01:45.129Z
#
#                                    created_by_ref  \
# 0  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [TEMP.Veles](https://attack.mitre.org/groups/G...
# 1  [APT39](https://attack.mitre.org/groups/G0087)...
# 2  [Stolen Pencil](https://attack.mitre.org/group...
# 3  [FIN4](https://attack.mitre.org/groups/G0085) ...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/groups/G008...
# 1  [{'external_id': 'G0087', 'source_name': 'mitr...
# 2  [{'external_id': 'G0086', 'source_name': 'mitr...
# 3  [{'url': 'https://attack.mitre.org/groups/G008...
#
#                                                   id  \
# 0  intrusion-set--9538b1a4-4120-4e2d-bf59-3b11fca...
# 1  intrusion-set--44e43fad-ffcb-4210-abcf-eaaed97...
# 2  intrusion-set--7a0d4c09-dfe7-4fa2-965a-1a0e42f...
# 3  intrusion-set--d0b3393b-3bec-4ba3-bda9-199d30d...
#
#                    modified           name  \
# 0  2019-04-29T18:59:16.079Z     TEMP.Veles
# 1  2019-04-29T18:16:38.235Z          APT39
# 2  2019-04-19T18:38:31.839Z  Stolen Pencil
# 3  2019-04-18T20:19:49.089Z           FIN4
#
#                                  object_marking_refs revoked           type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
#
#   x_mitre_contributors x_mitre_version
# 0                  NaN             1.0
# 1                  NaN             2.0
# 2                  NaN             1.0
# 3                  NaN             1.0

# %% [markdown]
# **Showing the schema of Groups**

# %%
list(df)
# Out:
# ['aliases',
#  'created',
#  'created_by_ref',
#  'description',
#  'external_references',
#  'id',
#  'modified',
#  'name',
#  'object_marking_refs',
#  'revoked',
#  'type',
#  'x_mitre_contributors',
#  'x_mitre_version']

# %% [markdown]
# **Showing one Groups example**

# %%
groups[0]
# Out:
# {'external_references': [{'url': 'https://attack.mitre.org/groups/G0088',
#    'source_name': 'mitre-attack',
#    'external_id': 'G0088'},
#   {'source_name': 'TEMP.Veles',
#    'description': '(Citation: FireEye TRITON 2019)'},
#   {'source_name': 'XENOTIME',
#    'description': 'The activity group XENOTIME, as defined by Dragos, has overlaps with activity reported upon by FireEye about TEMP.Veles as well as the actors behind TRITON.(Citation: Dragos Xenotime 2018)(Citation: Pylos Xenotime 2019)(Citation: FireEye TRITON 2019)(Citation: FireEye TEMP.Veles 2018 )'},
#   {'url': 'https://www.fireeye.com/blog/threat-research/2019/04/triton-actor-ttp-profile-custom-attack-tools-detections.html',
#    'source_name': 'FireEye TRITON 2019',
#    'description': 'Miller, S, et al. (2019, April 10). TRITON Actor TTP Profile, Custom Attack Tools, Detections, and ATT&CK Mapping. Retrieved April 16, 2019.'},
#   {'url': 'https://www.fireeye.com/blog/threat-research/2018/10/triton-attribution-russian-government-owned-lab-most-likely-built-tools.html ',
#    'source_name': 'FireEye TEMP.Veles 2018',
#    'description': 'FireEye Intelligence . (2018, October 23). TRITON Attribution: Russian Government-Owned Lab Most Likely Built Custom Intrusion Tools for TRITON Attackers. Retrieved April 16, 2019.'},
#   {'url': 'https://www.fireeye.com/content/dam/fireeye-www/blog/files/TRITON_Appendix_C.html',
#    'source_name': 'FireEye TEMP.Veles JSON April 2019',
#    'description': 'Miller, S., et al. (2019, April 10). TRITON Appendix C. Retrieved April 29, 2019.'},
#   {'url': 'https://dragos.com/resource/xenotime/',
#    'source_name': 'Dragos Xenotime 2018',
#    'description': 'Dragos, Inc.. (n.d.). Xenotime. Retrieved April 16, 2019.'},
#   {'url': 'https://pylos.co/2019/04/12/a-xenotime-to-remember-veles-in-the-wild/',
#    'source_name': 'Pylos Xenotime 2019',
#    'description': 'Slowik, J.. (2019, April 12). A XENOTIME to Remember: Veles in the Wild. Retrieved April 16, 2019.'},
#   {'url': 'https://www.fireeye.com/blog/threat-research/2018/10/triton-attribution-russian-government-owned-lab-most-likely-built-tools.html ',
#    'source_name': 'FireEye TEMP.Veles 2018 ',
#    'description': 'FireEye Intelligence . (2018, October 23). TRITON Attribution: Russian Government-Owned Lab Most Likely Built Custom Intrusion Tools for TRITON Attackers. Retrieved April 16, 2019.'}],
#  'object_marking_refs': ['marking-definition--fa42a846-8d90-4e51-bc29-71d5b4802168'],
#  'aliases': ['TEMP.Veles', 'XENOTIME'],
#  'id': 'intrusion-set--9538b1a4-4120-4e2d-bf59-3b11fcab05a4',
#  'name': 'TEMP.Veles',
#  'created': '2019-04-16T15:14:38.533Z',
#  'modified': '2019-04-29T18:59:16.079Z',
#  'type': 'intrusion-set',
#  'created_by_ref': 'identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5',
#  'description': '[TEMP.Veles](https://attack.mitre.org/groups/G0088) is a Russia-based threat group that has targeted critical infrastructure. The group has been observed utilizing TRITON, a malware framework designed to manipulate industrial safety systems.(Citation: FireEye TRITON 2019)(Citation: FireEye TEMP.Veles 2018)(Citation: FireEye TEMP.Veles JSON April 2019)',
#  'x_mitre_version': '1.0'}

# %% [markdown]
# ### Get All Malware objects from ATT&CK Results (Locally)

# %%
print("Number of Malware in ATT&CK")
print(len(all_attack['malware']))
# Out:
# Number of Malware in ATT&CK
# 321

# %%
malware = []
for t in all_attack['malware']:
    malware.append(json.loads(t.serialize()))
df = json_normalize(malware)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-23T18:41:36.914Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-19T16:40:24.922Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-19T15:30:36.593Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-17T19:18:00.270Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [CoinTicker](https://attack.mitre.org/software...
# 1  [Ebury](https://attack.mitre.org/software/S037...
# 2  [HOPLIGHT](https://attack.mitre.org/software/S...
# 3  [Remexi](https://attack.mitre.org/software/S03...
#
#                                  external_references  \
# 0  [{'external_id': 'S0369', 'source_name': 'mitr...
# 1  [{'external_id': 'S0377', 'source_name': 'mitr...
# 2  [{'external_id': 'S0376', 'source_name': 'mitr...
# 3  [{'external_id': 'S0375', 'source_name': 'mitr...
#
#                                               id     labels  \
# 0  malware--d1531eaa-9e17-473e-a680-3298469662c3  [malware]
# 1  malware--d6b3fcd0-1c86-4350-96f0-965ed02fcc51  [malware]
# 2  malware--454fe82d-6fd2-4ac6-91ab-28a33fe01369  [malware]
# 3  malware--ecc2f65a-b452-4eaf-9689-7e181f17f7a5  [malware]
#
#                    modified        name  \
# 0  2019-04-29T21:19:34.739Z  CoinTicker
# 1  2019-04-26T20:14:18.000Z       Ebury
# 2  2019-04-22T19:41:53.168Z    HOPLIGHT
# 3  2019-04-22T20:18:06.862Z      Remexi
#
#                                  object_marking_refs revoked     type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  malware
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  malware
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  malware
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  malware
#
#   x_mitre_aliases             x_mitre_contributors x_mitre_old_attack_id  \
# 0    [CoinTicker]       [Richie Cyrus, SpecterOps]                   NaN
# 1         [Ebury]  [Marc-Etienne M.Léveillé, ESET]                   NaN
# 2      [HOPLIGHT]                              NaN                   NaN
# 3        [Remexi]                              NaN                   NaN
#
#   x_mitre_platforms x_mitre_version
# 0           [macOS]             1.0
# 1           [Linux]             1.0
# 2         [Windows]             1.0
# 3         [Windows]             1.0

# %% [markdown]
# **Showing the schema of Malware**

# %%
list(df)
# Out:
# ['created',
#  'created_by_ref',
#  'description',
#  'external_references',
#  'id',
#  'labels',
#  'modified',
#  'name',
#  'object_marking_refs',
#  'revoked',
#  'type',
#  'x_mitre_aliases',
#  'x_mitre_contributors',
#  'x_mitre_old_attack_id',
#  'x_mitre_platforms',
#  'x_mitre_version']

# %% [markdown]
# **Showing one Malware example**

# %%
malware[0]
# Out:
# {'external_references': [{'external_id': 'S0369',
#    'source_name': 'mitre-attack',
#    'url': 'https://attack.mitre.org/software/S0369'},
#   {'url': 'https://blog.malwarebytes.com/threat-analysis/2018/10/mac-cryptocurrency-ticker-app-installs-backdoors/',
#    'source_name': 'CoinTicker 2019',
#    'description': 'Thomas Reed. (2018, October 29). Mac cryptocurrency ticker app installs backdoors. Retrieved April 23, 2019.'}],
#  'object_marking_refs': ['marking-definition--fa42a846-8d90-4e51-bc29-71d5b4802168'],
#  'modified': '2019-04-29T21:19:34.739Z',
#  'created_by_ref': 'identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5',
#  'id': 'malware--d1531eaa-9e17-473e-a680-3298469662c3',
#  'name': 'CoinTicker',
#  'created': '2019-04-23T18:41:36.914Z',
#  'labels': ['malware'],
#  'type': 'malware',
#  'description': '[CoinTicker](https://attack.mitre.org/software/S0369) is a malicious application that poses as a cryptocurrency price ticker and installs components of the open source backdoors EvilOSX and EggShell.(Citation: CoinTicker 2019)',
#  'x_mitre_contributors': ['Richie Cyrus, SpecterOps'],
#  'x_mitre_aliases': ['CoinTicker'],
#  'x_mitre_platforms': ['macOS'],
#  'x_mitre_version': '1.0'}

# %% [markdown]
# ### Get All Tools from ATT&CK Results (Locally)

# %%
print("Number of Tools in ATT&CK")
print(len(all_attack['tools']))
# Out:
# Number of Tools in ATT&CK
# 57

# %%
tools = []
for t in all_attack['tools']:
    tools.append(json.loads(t.serialize()))
df = json_normalize(tools)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-23T12:31:58.125Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-03-25T12:30:40.919Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-03-11T14:13:40.648Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-02-19T19:17:14.971Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [PoshC2](https://attack.mitre.org/software/S03...
# 1  [RawDisk](https://attack.mitre.org/software/S0...
# 2  [Empire](https://attack.mitre.org/software/S03...
# 3  [Expand](https://attack.mitre.org/software/S03...
#
#                                  external_references  \
# 0  [{'external_id': 'S0378', 'source_name': 'mitr...
# 1  [{'external_id': 'S0364', 'source_name': 'mitr...
# 2  [{'url': 'https://attack.mitre.org/software/S0...
# 3  [{'external_id': 'S0361', 'source_name': 'mitr...
#
#                                            id  labels  \
# 0  tool--4b57c098-f043-4da2-83ef-7588a6d426bc  [tool]
# 1  tool--3ffbdc1f-d2bf-41ab-91a2-c7b857e98079  [tool]
# 2  tool--3433a9e8-1c47-4320-b9bf-ed449061d1c3  [tool]
# 3  tool--ca656c25-44f1-471b-9d9f-e2a3bbb84973  [tool]
#
#                    modified     name  \
# 0  2019-04-23T18:29:12.005Z   PoshC2
# 1  2019-04-19T19:04:55.892Z  RawDisk
# 2  2019-04-24T20:24:34.115Z   Empire
# 3  2019-04-19T18:52:30.033Z   Expand
#
#                                  object_marking_refs  type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  tool
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  tool
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  tool
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  tool
#
#                        x_mitre_aliases             x_mitre_contributors  \
# 0                             [PoshC2]                              NaN
# 1                            [RawDisk]                              NaN
# 2  [Empire, EmPyre, PowerShell Empire]                              NaN
# 3                             [Expand]  [Matthew Demaske, Adaptforward]
#
#   x_mitre_old_attack_id        x_mitre_platforms x_mitre_version
# 0                   NaN  [Windows, Linux, macOS]             1.0
# 1                   NaN                [Windows]             1.0
# 2                   NaN  [Linux, macOS, Windows]             1.0
# 3                   NaN                [Windows]             1.0

# %% [markdown]
# **Showing the schema of Tools**

# %%
list(df)
# Out:
# ['created',
#  'created_by_ref',
#  'description',
#  'external_references',
#  'id',
#  'labels',
#  'modified',
#  'name',
#  'object_marking_refs',
#  'type',
#  'x_mitre_aliases',
#  'x_mitre_contributors',
#  'x_mitre_old_attack_id',
#  'x_mitre_platforms',
#  'x_mitre_version']

# %% [markdown]
# **Showing one Tool example**

# %%
tools[0]
# Out:
# {'external_references': [{'external_id': 'S0378',
#    'source_name': 'mitre-attack',
#    'url': 'https://attack.mitre.org/software/S0378'},
#   {'url': 'https://github.com/nettitude/PoshC2',
#    'source_name': 'GitHub PoshC2',
#    'description': 'Nettitude. (2016, June 8). PoshC2: Powershell C2 Server and Implants. Retrieved April 23, 2019.'}],
#  'object_marking_refs': ['marking-definition--fa42a846-8d90-4e51-bc29-71d5b4802168'],
#  'modified': '2019-04-23T18:29:12.005Z',
#  'created_by_ref': 'identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5',
#  'id': 'tool--4b57c098-f043-4da2-83ef-7588a6d426bc',
#  'name': 'PoshC2',
#  'created': '2019-04-23T12:31:58.125Z',
#  'labels': ['tool'],
#  'type': 'tool',
#  'description': '[PoshC2](https://attack.mitre.org/software/S0378) is an open source remote administration and post-exploitation framework that is publicly available on GitHub. The server-side components of the tool are primarily written in Python, while the implants are written in [PowerShell](https://attack.mitre.org/techniques/T1086). Although [PoshC2](https://attack.mitre.org/software/S0378) is primarily focused on Windows implantation, it does contain a basic Python dropper for Linux/macOS.(Citation: GitHub PoshC2)',
#  'x_mitre_aliases': ['PoshC2'],
#  'x_mitre_platforms': ['Windows', 'Linux', 'macOS'],
#  'x_mitre_version': '1.0'}

# %% [markdown]
# ### Get All Relationships from ATT&CK Results (Locally)

# %%
print("Number of Relationships in ATT&CK")
print(len(all_attack['relationships']))
# Out:
# Number of Relationships in ATT&CK
# 5223

# %%
relationships = []
for t in all_attack['relationships']:
    relationships.append(json.loads(t.serialize()))
df = json_normalize(relationships)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-29T15:54:23.241Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-29T15:53:48.468Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-26T20:07:36.100Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-26T19:30:33.727Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0                                                NaN
# 1  [APT39](https://attack.mitre.org/groups/G0087)...
# 2  [Ebury](https://attack.mitre.org/software/S037...
# 3                                                NaN
#
#                                  external_references  \
# 0  [{'url': 'https://www.symantec.com/connect/blo...
# 1  [{'url': 'https://www.symantec.com/connect/blo...
# 2  [{'url': 'https://www.welivesecurity.com/2014/...
# 3                                                NaN
#
#                                                   id  \
# 0  relationship--2a37ddb3-56ef-4c2d-bec7-d6060eb0...
# 1  relationship--439344c5-67e0-4d38-9b91-866392e5...
# 2  relationship--9af6241d-355a-4673-b772-8384a718...
# 3  relationship--dfd5d379-9af4-4234-a0b2-a1591197...
#
#                    modified  \
# 0  2019-04-29T18:16:38.854Z
# 1  2019-04-29T18:16:38.727Z
# 2  2019-04-26T20:14:18.255Z
# 3  2019-04-26T19:30:33.727Z
#
#                                  object_marking_refs relationship_type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...         mitigates
#
#                                           source_ref  \
# 0  intrusion-set--44e43fad-ffcb-4210-abcf-eaaed97...
# 1  intrusion-set--44e43fad-ffcb-4210-abcf-eaaed97...
# 2      malware--d6b3fcd0-1c86-4350-96f0-965ed02fcc51
# 3  course-of-action--70886857-0f19-4caa-b081-5483...
#
#                                           target_ref          type
# 0      malware--ecc2f65a-b452-4eaf-9689-7e181f17f7a5  relationship
# 1  attack-pattern--03d7999c-1f4c-42cc-8373-e7690d...  relationship
# 2  attack-pattern--b3d682b6-98f2-4fb0-aa3b-b4df00...  relationship
# 3  attack-pattern--f5bb433e-bdf6-4781-84bc-35e97e...  relationship

# %% [markdown]
# **Showing the schema of Relationships**

# %%
list(df)
# Out:
# ['created',
#  'created_by_ref',
#  'description',
#  'external_references',
#  'id',
#  'modified',
#  'object_marking_refs',
#  'relationship_type',
#  'source_ref',
#  'target_ref',
#  'type']

# %% [markdown]
# **Showing one Relationship example**

# %%
relationships[0]
# Out:
# {'object_marking_refs': ['marking-definition--fa42a846-8d90-4e51-bc29-71d5b4802168'],
#  'id': 'relationship--2a37ddb3-56ef-4c2d-bec7-d6060eb0215a',
#  'external_references': [{'url': 'https://www.symantec.com/connect/blogs/iran-based-attackers-use-back-door-threats-spy-middle-eastern-targets',
#    'source_name': 'Symantec Chafer Dec 2015',
#    'description': 'Symantec Security Response. (2015, December 7). Iran-based attackers use back door threats to spy on Middle Eastern targets. Retrieved April 17, 2019.'},
#   {'url': 'https://securelist.com/chafer-used-remexi-malware/89538/',
#    'source_name': 'Securelist Remexi Jan 2019',
#    'description': 'Legezo, D. (2019, January 30). Chafer used Remexi malware to spy on Iran-based foreign diplomatic entities. Retrieved April 17, 2019.'}],
#  'created': '2019-04-29T15:54:23.241Z',
#  'modified': '2019-04-29T18:16:38.854Z',
#  'type': 'relationship',
#  'created_by_ref': 'identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5',
#  'source_ref': 'intrusion-set--44e43fad-ffcb-4210-abcf-eaaed9735f80',
#  'relationship_type': 'uses',
#  'target_ref': 'malware--ecc2f65a-b452-4eaf-9689-7e181f17f7a5'}

# %% [markdown]
# ### Get All Enterprise ATT&CK ONLY from Results (Locally)
# * We can also grab the results from each get_all_* function that we run earlier, and start getting specific stix object types such as techniques, mitigations, groups, malware, tools and relationships on each specific matrix.
# * It is important to remember that the stix objec information is being retrieved from the results of the initial three **get_all_*** functions and not querying the TAXII Server every time we want to get information about a specific stix object type.

# %% [markdown]
# **Enterprise Techniques**

# %%
print("Number of Techniques in Enterprise ATT&CK")
print(len(all_enterprise['techniques']))
# Out:
# Number of Techniques in Enterprise ATT&CK
# 244

# %%
techniques = []
for t in all_enterprise['techniques']:
    techniques.append(json.loads(t.serialize()))
df = json_normalize(techniques)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-25T20:53:07.719Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-23T15:34:30.008Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-18T11:00:55.862Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-17T22:22:24.505Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  Adversaries may attempt to make payloads diffi...
# 1  Systemd services can be used to establish pers...
# 2  Adversaries may perform Endpoint Denial of Ser...
# 3  Adversaries may check for the presence of a vi...
#
#                                  external_references  \
# 0  [{'external_id': 'T1500', 'source_name': 'mitr...
# 1  [{'external_id': 'T1501', 'source_name': 'mitr...
# 2  [{'external_id': 'T1499', 'source_name': 'mitr...
# 3  [{'external_id': 'T1497', 'source_name': 'mitr...
#
#                                                   id  \
# 0  attack-pattern--cf7b3a06-8b42-4c33-bbe9-012120...
# 1  attack-pattern--0fff2797-19cb-41ea-a5f1-8a9303...
# 2  attack-pattern--c675646d-e204-4aa8-978d-e3d6d6...
# 3  attack-pattern--82caa33e-d11a-433a-94ea-9b5a5f...
#
#                                    kill_chain_phases  \
# 0  [{'phase_name': 'defense-evasion', 'kill_chain...
# 1  [{'phase_name': 'persistence', 'kill_chain_nam...
# 2  [{'phase_name': 'impact', 'kill_chain_name': '...
# 3  [{'phase_name': 'defense-evasion', 'kill_chain...
#
#                    modified                            name  \
# 0  2019-04-29T21:13:49.686Z          Compile After Delivery
# 1  2019-04-29T14:14:08.450Z                 Systemd Service
# 2  2019-04-29T13:20:36.795Z      Endpoint Denial of Service
# 3  2019-04-29T14:17:25.403Z  Virtualization/Sandbox Evasion
#
#                                  object_marking_refs            type  ...  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern  ...
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern  ...
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern  ...
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern  ...
#
#                             x_mitre_defense_bypassed  \
# 0  [Static File Analysis, Binary Analysis, Anti-v...
# 1                                                NaN
# 2                                                NaN
# 3  [Anti-virus, Host forensic analysis, Signature...
#
#                                    x_mitre_detection  \
# 0  Monitor the execution file paths and command-l...
# 1  Systemd service unit files may be detected by ...
# 2  Detection of Endpoint DoS can sometimes be ach...
# 3  Virtualization, sandbox, and related discovery...
#
#   x_mitre_effective_permissions x_mitre_impact_type  \
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2                           NaN      [Availability]
# 3                           NaN                 NaN
#
#   x_mitre_network_requirements x_mitre_permissions_required  \
# 0                          NaN                       [User]
# 1                          NaN                 [root, User]
# 2                          NaN                          NaN
# 3                          NaN                          NaN
#
#          x_mitre_platforms x_mitre_remote_support  \
# 0  [Linux, macOS, Windows]                    NaN
# 1                  [Linux]                    NaN
# 2  [Linux, macOS, Windows]                    NaN
# 3                [Windows]                    NaN
#
#                          x_mitre_system_requirements x_mitre_version
# 0  [Compiler software (either native to the syste...             1.0
# 1                                                NaN             1.0
# 2                                                NaN             1.0
# 3                                                NaN             1.0
#
# [4 rows x 22 columns]

# %% [markdown]
# **Enterprise Mitigations**

# %%
print("Number of Mitigations in Enterprise ATT&CK")
print(len(all_enterprise['mitigations']))
# Out:
# Number of Mitigations in Enterprise ATT&CK
# 241

# %%
mitigations = []
for t in all_enterprise['mitigations']:
    mitigations.append(json.loads(t.serialize()))
df = json_normalize(mitigations)
df[0:5]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-26T19:30:33.607Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-25T20:53:07.814Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-24T17:03:39.689Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-24T17:02:25.107Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 4  2019-04-24T17:01:10.433Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  Prevent adversary access to privileged account...
# 1  This type of technique cannot be easily mitiga...
# 2  Identify critical business and system processe...
# 3  Identify critical business and system processe...
# 4  Ensure proper process, registry, and file perm...
#
#                                  external_references  \
# 0  [{'external_id': 'T1495', 'source_name': 'mitr...
# 1  [{'external_id': 'T1502', 'source_name': 'mitr...
# 2  [{'external_id': 'T1493', 'source_name': 'mitr...
# 3  [{'external_id': 'T1492', 'source_name': 'mitr...
# 4  [{'external_id': 'T1489', 'source_name': 'mitr...
#
#                                                   id  \
# 0  course-of-action--70886857-0f19-4caa-b081-5483...
# 1  course-of-action--ae56a49d-5281-45c5-ab95-70a1...
# 2  course-of-action--245075bc-f992-4d89-af8c-834c...
# 3  course-of-action--e9362d25-4427-446b-99e8-b8f0...
# 4  course-of-action--417fed8c-bd76-48b5-90a2-a888...
#
#                    modified                                      name  \
# 0  2019-04-26T19:41:45.126Z            Firmware Corruption Mitigation
# 1  2019-04-26T14:19:09.167Z         Compile After Delivery Mitigation
# 2  2019-04-26T18:48:27.528Z  Transmitted Data Manipulation Mitigation
# 3  2019-04-26T18:57:01.963Z       Stored Data Manipulation Mitigation
# 4  2019-04-25T20:13:29.375Z                   Service Stop Mitigation
#
#                                  object_marking_refs              type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 4  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
#
#   x_mitre_version
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0

# %% [markdown]
# **Enterprise Groups**

# %%
print("Number of Groups in Enterprise ATT&CK")
print(len(all_enterprise['groups']))
# Out:
# Number of Groups in Enterprise ATT&CK
# 88

# %%
groups = []
for t in all_enterprise['groups']:
    groups.append(json.loads(t.serialize()))
df = json_normalize(groups)
df[0:4]
# Out:
#                   aliases                   created  \
# 0  [TEMP.Veles, XENOTIME]  2019-04-16T15:14:38.533Z
# 1         [APT39, Chafer]  2019-02-19T16:01:38.585Z
# 2         [Stolen Pencil]  2019-02-05T17:56:55.233Z
# 3                  [FIN4]  2019-01-31T02:01:45.129Z
#
#                                    created_by_ref  \
# 0  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [TEMP.Veles](https://attack.mitre.org/groups/G...
# 1  [APT39](https://attack.mitre.org/groups/G0087)...
# 2  [Stolen Pencil](https://attack.mitre.org/group...
# 3  [FIN4](https://attack.mitre.org/groups/G0085) ...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/groups/G008...
# 1  [{'external_id': 'G0087', 'source_name': 'mitr...
# 2  [{'external_id': 'G0086', 'source_name': 'mitr...
# 3  [{'url': 'https://attack.mitre.org/groups/G008...
#
#                                                   id  \
# 0  intrusion-set--9538b1a4-4120-4e2d-bf59-3b11fca...
# 1  intrusion-set--44e43fad-ffcb-4210-abcf-eaaed97...
# 2  intrusion-set--7a0d4c09-dfe7-4fa2-965a-1a0e42f...
# 3  intrusion-set--d0b3393b-3bec-4ba3-bda9-199d30d...
#
#                    modified           name  \
# 0  2019-04-29T18:59:16.079Z     TEMP.Veles
# 1  2019-04-29T18:16:38.235Z          APT39
# 2  2019-04-19T18:38:31.839Z  Stolen Pencil
# 3  2019-04-18T20:19:49.089Z           FIN4
#
#                                  object_marking_refs revoked           type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
#
#   x_mitre_contributors x_mitre_version
# 0                  NaN             1.0
# 1                  NaN             2.0
# 2                  NaN             1.0
# 3                  NaN             1.0

# %% [markdown]
# **Enterprise Malware**

# %%
print("Number of Malware objects in Enterprise ATT&CK")
print(len(all_enterprise['malware']))
# Out:
# Number of Malware objects in Enterprise ATT&CK
# 278

# %%
malware = []
for t in all_enterprise['malware']:
    malware.append(json.loads(t.serialize()))
df = json_normalize(malware)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-23T18:41:36.914Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-19T16:40:24.922Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-19T15:30:36.593Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-17T19:18:00.270Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [CoinTicker](https://attack.mitre.org/software...
# 1  [Ebury](https://attack.mitre.org/software/S037...
# 2  [HOPLIGHT](https://attack.mitre.org/software/S...
# 3  [Remexi](https://attack.mitre.org/software/S03...
#
#                                  external_references  \
# 0  [{'external_id': 'S0369', 'source_name': 'mitr...
# 1  [{'external_id': 'S0377', 'source_name': 'mitr...
# 2  [{'external_id': 'S0376', 'source_name': 'mitr...
# 3  [{'external_id': 'S0375', 'source_name': 'mitr...
#
#                                               id     labels  \
# 0  malware--d1531eaa-9e17-473e-a680-3298469662c3  [malware]
# 1  malware--d6b3fcd0-1c86-4350-96f0-965ed02fcc51  [malware]
# 2  malware--454fe82d-6fd2-4ac6-91ab-28a33fe01369  [malware]
# 3  malware--ecc2f65a-b452-4eaf-9689-7e181f17f7a5  [malware]
#
#                    modified        name  \
# 0  2019-04-29T21:19:34.739Z  CoinTicker
# 1  2019-04-26T20:14:18.000Z       Ebury
# 2  2019-04-22T19:41:53.168Z    HOPLIGHT
# 3  2019-04-22T20:18:06.862Z      Remexi
#
#                                  object_marking_refs revoked     type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  malware
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  malware
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  malware
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  malware
#
#   x_mitre_aliases             x_mitre_contributors x_mitre_old_attack_id  \
# 0    [CoinTicker]       [Richie Cyrus, SpecterOps]                   NaN
# 1         [Ebury]  [Marc-Etienne M.Léveillé, ESET]                   NaN
# 2      [HOPLIGHT]                              NaN                   NaN
# 3        [Remexi]                              NaN                   NaN
#
#   x_mitre_platforms x_mitre_version
# 0           [macOS]             1.0
# 1           [Linux]             1.0
# 2         [Windows]             1.0
# 3         [Windows]             1.0

# %% [markdown]
# **Enterprise Tools**

# %%
print("Number of Tools in Enterprise ATT&CK")
print(len(all_enterprise['tools']))
# Out:
# Number of Tools in Enterprise ATT&CK
# 56

# %%
tools = []
for t in all_enterprise['tools']:
    tools.append(json.loads(t.serialize()))
df = json_normalize(tools)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-23T12:31:58.125Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-03-25T12:30:40.919Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-03-11T14:13:40.648Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-02-19T19:17:14.971Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [PoshC2](https://attack.mitre.org/software/S03...
# 1  [RawDisk](https://attack.mitre.org/software/S0...
# 2  [Empire](https://attack.mitre.org/software/S03...
# 3  [Expand](https://attack.mitre.org/software/S03...
#
#                                  external_references  \
# 0  [{'external_id': 'S0378', 'source_name': 'mitr...
# 1  [{'external_id': 'S0364', 'source_name': 'mitr...
# 2  [{'url': 'https://attack.mitre.org/software/S0...
# 3  [{'external_id': 'S0361', 'source_name': 'mitr...
#
#                                            id  labels  \
# 0  tool--4b57c098-f043-4da2-83ef-7588a6d426bc  [tool]
# 1  tool--3ffbdc1f-d2bf-41ab-91a2-c7b857e98079  [tool]
# 2  tool--3433a9e8-1c47-4320-b9bf-ed449061d1c3  [tool]
# 3  tool--ca656c25-44f1-471b-9d9f-e2a3bbb84973  [tool]
#
#                    modified     name  \
# 0  2019-04-23T18:29:12.005Z   PoshC2
# 1  2019-04-19T19:04:55.892Z  RawDisk
# 2  2019-04-24T20:24:34.115Z   Empire
# 3  2019-04-19T18:52:30.033Z   Expand
#
#                                  object_marking_refs  type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  tool
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  tool
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  tool
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  tool
#
#                        x_mitre_aliases             x_mitre_contributors  \
# 0                             [PoshC2]                              NaN
# 1                            [RawDisk]                              NaN
# 2  [Empire, EmPyre, PowerShell Empire]                              NaN
# 3                             [Expand]  [Matthew Demaske, Adaptforward]
#
#          x_mitre_platforms x_mitre_version
# 0  [Windows, Linux, macOS]             1.0
# 1                [Windows]             1.0
# 2  [Linux, macOS, Windows]             1.0
# 3                [Windows]             1.0

# %% [markdown]
# **Enterprise Relationships**

# %%
print("Number of Relationships in Enterprise ATT&CK")
print(len(all_enterprise['relationships']))
# Out:
# Number of Relationships in Enterprise ATT&CK
# 4852

# %%
relations = []
for t in all_enterprise['relationships']:
    relations.append(json.loads(t.serialize()))
df = json_normalize(relations)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-29T15:54:23.241Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-29T15:53:48.468Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-26T20:07:36.100Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-26T19:30:33.727Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0                                                NaN
# 1  [APT39](https://attack.mitre.org/groups/G0087)...
# 2  [Ebury](https://attack.mitre.org/software/S037...
# 3                                                NaN
#
#                                  external_references  \
# 0  [{'url': 'https://www.symantec.com/connect/blo...
# 1  [{'url': 'https://www.symantec.com/connect/blo...
# 2  [{'url': 'https://www.welivesecurity.com/2014/...
# 3                                                NaN
#
#                                                   id  \
# 0  relationship--2a37ddb3-56ef-4c2d-bec7-d6060eb0...
# 1  relationship--439344c5-67e0-4d38-9b91-866392e5...
# 2  relationship--9af6241d-355a-4673-b772-8384a718...
# 3  relationship--dfd5d379-9af4-4234-a0b2-a1591197...
#
#                    modified  \
# 0  2019-04-29T18:16:38.854Z
# 1  2019-04-29T18:16:38.727Z
# 2  2019-04-26T20:14:18.255Z
# 3  2019-04-26T19:30:33.727Z
#
#                                  object_marking_refs relationship_type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...         mitigates
#
#                                           source_ref  \
# 0  intrusion-set--44e43fad-ffcb-4210-abcf-eaaed97...
# 1  intrusion-set--44e43fad-ffcb-4210-abcf-eaaed97...
# 2      malware--d6b3fcd0-1c86-4350-96f0-965ed02fcc51
# 3  course-of-action--70886857-0f19-4caa-b081-5483...
#
#                                           target_ref          type
# 0      malware--ecc2f65a-b452-4eaf-9689-7e181f17f7a5  relationship
# 1  attack-pattern--03d7999c-1f4c-42cc-8373-e7690d...  relationship
# 2  attack-pattern--b3d682b6-98f2-4fb0-aa3b-b4df00...  relationship
# 3  attack-pattern--f5bb433e-bdf6-4781-84bc-35e97e...  relationship

# %% [markdown]
# ### Get All PRE-ATT&CK ONLY from Results (Locally)

# %% [markdown]
# **PRE Techniques**

# %%
print("Number of Techniques in PRE-ATT&CK")
print(len(all_pre['techniques']))
# Out:
# Number of Techniques in PRE-ATT&CK
# 174

# %%
techniques = []
for t in all_pre['techniques']:
    techniques.append(json.loads(t.serialize()))
df = json_normalize(techniques)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2018-04-18T17:59:24.739Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2017-12-14T16:46:06.044Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2017-12-14T16:46:06.044Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2017-12-14T16:46:06.044Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  Spearphishing for information is a specific va...
# 1  A wide variety of cloud, virtual private servi...
# 2  Code signing is the process of digitally signi...
# 3  An adversary will assess collected information...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/techniques/...
# 1  [{'url': 'https://attack.mitre.org/techniques/...
# 2  [{'url': 'https://attack.mitre.org/techniques/...
# 3  [{'url': 'https://attack.mitre.org/techniques/...
#
#                                                   id  \
# 0  attack-pattern--b182f29c-2505-4b32-a000-0440ef...
# 1  attack-pattern--795c1a92-3a26-453e-b99a-6a566a...
# 2  attack-pattern--03f4a766-7a21-4b5e-9ccf-e0cf42...
# 3  attack-pattern--773950e1-090c-488b-a480-9ff236...
#
#                                    kill_chain_phases  \
# 0  [{'phase_name': 'technical-information-gatheri...
# 1  [{'phase_name': 'establish-&-maintain-infrastr...
# 2  [{'phase_name': 'establish-&-maintain-infrastr...
# 3  [{'phase_name': 'technical-weakness-identifica...
#
#                    modified  \
# 0  2018-10-17T00:14:20.652Z
# 1  2018-10-17T00:14:20.652Z
# 2  2019-02-19T18:56:56.071Z
# 3  2018-10-17T00:14:20.652Z
#
#                                                 name  \
# 0                      Spearphishing for Information
# 1  Acquire and/or use 3rd party infrastructure se...
# 2  Acquire or compromise 3rd party signing certif...
# 3                             Analyze data collected
#
#                                  object_marking_refs            type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern
#
#   x_mitre_deprecated x_mitre_detectable_by_common_defenses  \
# 0                NaN                               Partial
# 1                NaN                                    No
# 2                NaN                                    No
# 3                NaN                                    No
#
#    x_mitre_detectable_by_common_defenses_explanation  \
# 0  Depending on the specific method of phishing, ...
# 1  Hard to differentiate from standard business o...
# 2  Defender will not know what certificates an ad...
# 3  This can be done offline after the data has be...
#
#   x_mitre_difficulty_for_adversary  \
# 0                              Yes
# 1                              Yes
# 2                               No
# 3                              Yes
#
#         x_mitre_difficulty_for_adversary_explanation x_mitre_old_attack_id  \
# 0  Sending emails is trivial, and, over time, an ...             PRE-T1174
# 1  Wide variety of cloud/VPS/hosting/compute/stor...             PRE-T1106
# 2  It is trivial to purchase code signing certifi...             PRE-T1109
# 3  Many of the common tools highlight these weakn...             PRE-T1064
#
#   x_mitre_version
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0

# %% [markdown]
# **PRE Groups**

# %%
print("Number of Groups in PRE-ATT&CK")
print(len(all_pre['groups']))
# Out:
# Number of Groups in PRE-ATT&CK
# 7

# %%
groups = []
for t in all_pre['groups']:
    groups.append(json.loads(t.serialize()))
df = json_normalize(groups)
df[0:4]
# Out:
#                   aliases                   created  \
# 0  [TEMP.Veles, XENOTIME]  2019-04-16T15:14:38.533Z
# 1     [APT17, Deputy Dog]  2017-05-31T21:31:57.307Z
# 2                 [APT16]  2017-05-31T21:31:56.270Z
# 3          [Night Dragon]  2017-05-31T21:31:51.643Z
#
#                                    created_by_ref  \
# 0  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [TEMP.Veles](https://attack.mitre.org/groups/G...
# 1  [APT17](https://attack.mitre.org/groups/G0025)...
# 2  [APT16](https://attack.mitre.org/groups/G0023)...
# 3  [Night Dragon](https://attack.mitre.org/groups...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/groups/G008...
# 1  [{'url': 'https://attack.mitre.org/groups/G002...
# 2  [{'url': 'https://attack.mitre.org/groups/G002...
# 3  [{'url': 'https://attack.mitre.org/groups/G001...
#
#                                                   id  \
# 0  intrusion-set--9538b1a4-4120-4e2d-bf59-3b11fca...
# 1  intrusion-set--090242d7-73fc-4738-af68-20162f7...
# 2  intrusion-set--d6e88e18-81e8-4709-82d8-973095d...
# 3  intrusion-set--23b6a0f5-fa95-46f9-a6f3-4549c5e...
#
#                    modified          name  \
# 0  2019-04-29T18:59:16.079Z    TEMP.Veles
# 1  2019-03-22T14:21:19.419Z         APT17
# 2  2019-03-22T14:20:45.561Z         APT16
# 3  2019-03-25T14:36:29.638Z  Night Dragon
#
#                                  object_marking_refs           type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  intrusion-set
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  intrusion-set
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  intrusion-set
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  intrusion-set
#
#   x_mitre_contributors x_mitre_version
# 0                  NaN             1.0
# 1                  NaN             1.0
# 2                  NaN             1.0
# 3                  NaN             1.1

# %% [markdown]
# **PRE Relationships**

# %%
print("Number of Relationships in PRE-ATT&CK")
print(len(all_pre['relationships']))
# Out:
# Number of Relationships in PRE-ATT&CK
# 70

# %%
relations = []
for t in all_pre['relationships']:
    relations.append(json.loads(t.serialize()))
df = json_normalize(relations)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-24T19:45:44.212Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-24T19:45:44.205Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-02-19T18:56:56.770Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-02-19T18:56:56.136Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [TEMP.Veles](https://attack.mitre.org/groups/G...
# 1  [TEMP.Veles](https://attack.mitre.org/groups/G...
# 2                                                NaN
# 3                                                NaN
#
#                                  external_references  \
# 0  [{'url': 'https://www.fireeye.com/blog/threat-...
# 1  [{'url': 'https://www.fireeye.com/blog/threat-...
# 2                                                NaN
# 3                                                NaN
#
#                                                   id  \
# 0  relationship--21842707-0f15-43bf-bc42-2bceadf2...
# 1  relationship--2d95ed6f-52e7-4708-af15-9a6c0839...
# 2  relationship--83379e43-4bc5-4c49-b0b3-f41161e8...
# 3  relationship--1aafdefb-304e-4998-87cc-81aad295...
#
#                    modified  \
# 0  2019-04-29T18:59:16.596Z
# 1  2019-04-29T18:59:16.595Z
# 2  2019-02-19T18:56:56.770Z
# 3  2019-02-19T18:56:56.136Z
#
#                                  object_marking_refs relationship_type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...        related-to
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...        related-to
#
#                                           source_ref  \
# 0  intrusion-set--9538b1a4-4120-4e2d-bf59-3b11fca...
# 1  intrusion-set--9538b1a4-4120-4e2d-bf59-3b11fca...
# 2  attack-pattern--e5164428-03ca-4336-a9a7-4d9ea1...
# 3  attack-pattern--03f4a766-7a21-4b5e-9ccf-e0cf42...
#
#                                           target_ref          type
# 0  attack-pattern--20a66013-8dab-4ca3-a67d-766c84...  relationship
# 1  attack-pattern--795c1a92-3a26-453e-b99a-6a566a...  relationship
# 2  attack-pattern--03f4a766-7a21-4b5e-9ccf-e0cf42...  relationship
# 3  attack-pattern--e5164428-03ca-4336-a9a7-4d9ea1...  relationship

# %% [markdown]
# ### Get All Mobile ATT&CK ONLY from Results (Locally)

# %% [markdown]
# **Mobile Techniques**

# %%
print("Number of Techniques in Mobile ATT&CK")
print(len(all_mobile['techniques']))
# Out:
# Number of Techniques in Mobile ATT&CK
# 82

# %%
techniques = []
for t in all_mobile['techniques']:
    techniques.append(json.loads(t.serialize()))
df = json_normalize(techniques)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-02-01T17:29:43.503Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2018-10-17T00:14:20.652Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2018-10-17T00:14:20.652Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2018-10-17T00:14:20.652Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  Adversaries may use an existing, legitimate ex...
# 1  Malicious applications are a common attack vec...
# 2  As further described in [Supply Chain Compromi...
# 3  Malicious applications are a common attack vec...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/techniques/...
# 1  [{'url': 'https://attack.mitre.org/techniques/...
# 2  [{'url': 'https://attack.mitre.org/techniques/...
# 3  [{'url': 'https://attack.mitre.org/techniques/...
#
#                                                   id  \
# 0  attack-pattern--c6a146ae-9c63-4606-97ff-e261e7...
# 1  attack-pattern--d9db3d46-66ca-44b4-9daa-1ef97c...
# 2  attack-pattern--0d95940f-9583-4e0f-824c-a42c1b...
# 3  attack-pattern--53263a67-075e-48fa-974b-91c5b5...
#
#                                    kill_chain_phases  \
# 0  [{'phase_name': 'command-and-control', 'kill_c...
# 1  [{'phase_name': 'initial-access', 'kill_chain_...
# 2  [{'phase_name': 'initial-access', 'kill_chain_...
# 3  [{'phase_name': 'initial-access', 'kill_chain_...
#
#                    modified                                            name  \
# 0  2019-02-01T17:29:43.503Z                                     Web Service
# 1  2019-02-03T17:31:51.215Z  Deliver Malicious App via Authorized App Store
# 2  2018-10-17T00:14:20.652Z                         Supply Chain Compromise
# 3  2019-02-03T14:08:44.916Z           Deliver Malicious App via Other Means
#
#                                  object_marking_refs revoked            type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  attack-pattern
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  attack-pattern
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  attack-pattern
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  attack-pattern
#
#                                    x_mitre_detection x_mitre_old_attack_id  \
# 0                                                NaN                   NaN
# 1  * An EMM/MDM or mobile threat defense solution...             MOB-T1078
# 2  * Insecure third-party libraries could be dete...             MOB-T1077
# 3  * An EMM/MDM or mobile threat defense solution...             MOB-T1079
#
#   x_mitre_platforms             x_mitre_tactic_type x_mitre_version
# 0    [Android, iOS]  [Post-Adversary Device Access]             1.0
# 1    [Android, iOS]  [Post-Adversary Device Access]             1.0
# 2    [Android, iOS]  [Post-Adversary Device Access]             1.0
# 3    [Android, iOS]  [Post-Adversary Device Access]             1.1

# %% [markdown]
# **Mobile Mitigations**

# %%
print("Number of Mitigations in Mobile ATT&CK")
print(len(all_mobile['mitigations']))
# Out:
# Number of Mitigations in Mobile ATT&CK
# 14

# %%
mitigations = []
for t in all_mobile['mitigations']:
    mitigations.append(json.loads(t.serialize()))
df = json_normalize(mitigations)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2017-10-25T14:48:53.732Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2017-10-25T14:48:53.318Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2017-10-25T14:48:52.933Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2017-10-25T14:48:52.601Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  This mitigation describes any guidance or trai...
# 1  An enterprise mobility management (EMM), also ...
# 2  Enable remote attestation capabilities when av...
# 3  A variety of methods exist that can be used to...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/mitigations...
# 1  [{'url': 'https://attack.mitre.org/mitigations...
# 2  [{'url': 'https://attack.mitre.org/mitigations...
# 3  [{'url': 'https://attack.mitre.org/mitigations...
#
#                                                   id  \
# 0  course-of-action--25dc1ce8-eb55-4333-ae30-a7cb...
# 1  course-of-action--649f7268-4c12-483b-ac84-4b7b...
# 2  course-of-action--ff4821f6-5afb-481b-8c0f-26c2...
# 3  course-of-action--cf2cccb1-cab8-431a-8ecf-f787...
#
#                    modified                                        name  \
# 0  2018-10-17T00:14:20.652Z              Application Developer Guidance
# 1  2018-10-17T00:14:20.652Z                           Enterprise Policy
# 2  2018-10-17T00:14:20.652Z                                 Attestation
# 3  2018-10-17T00:14:20.652Z  Deploy Compromised Device Detection Method
#
#                                  object_marking_refs              type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
#
#   x_mitre_old_attack_id x_mitre_version
# 0             MOB-M1013             1.0
# 1             MOB-M1012             1.0
# 2             MOB-M1002             1.0
# 3             MOB-M1010             1.0

# %% [markdown]
# **Mobile Groups**

# %%
print("Number of Groups in Mobile ATT&CK")
print(len(all_mobile['groups']))
# Out:
# Number of Groups in Mobile ATT&CK
# 1

# %%
groups = []
for t in all_mobile['groups']:
    groups.append(json.loads(t.serialize()))
df = json_normalize(groups)
df[0:4]
# Out:
#                                              aliases  \
# 0  [APT28, SNAKEMACKEREL, Swallowtail, Group 74, ...
#
#                     created                                  created_by_ref  \
# 0  2017-05-31T21:31:48.664Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [APT28](https://attack.mitre.org/groups/G0007)...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/groups/G000...
#
#                                                   id  \
# 0  intrusion-set--bef4c620-0787-42a8-a96d-b7eb6e8...
#
#                    modified   name  \
# 0  2019-04-29T18:16:13.040Z  APT28
#
#                                  object_marking_refs           type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  intrusion-set
#
#                                 x_mitre_contributors x_mitre_version
# 0  [Emily Ratliff, IBM, Richard Gold, Digital Sha...             2.0

# %% [markdown]
# **Mobile Malware**

# %%
print("Number of Malware in Mobile ATT&CK")
print(len(all_mobile['malware']))
# Out:
# Number of Malware in Mobile ATT&CK
# 43

# %%
malware = []
for t in all_mobile['malware']:
    malware.append(json.loads(t.serialize()))
df = json_normalize(malware)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2018-10-17T00:14:20.652Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2018-10-17T00:14:20.652Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2018-10-17T00:14:20.652Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2018-10-17T00:14:20.652Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [Judy](https://attack.mitre.org/software/S0325...
# 1  [SpyDealer](https://attack.mitre.org/software/...
# 2  [RedDrop](https://attack.mitre.org/software/S0...
# 3  [Skygofree](https://attack.mitre.org/software/...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/software/S0...
# 1  [{'url': 'https://attack.mitre.org/software/S0...
# 2  [{'url': 'https://attack.mitre.org/software/S0...
# 3  [{'url': 'https://attack.mitre.org/software/S0...
#
#                                               id     labels  \
# 0  malware--172444ab-97fc-4d94-b142-179452bfb760  [malware]
# 1  malware--86fc6f0c-86d9-473e-89f3-f50f3cb9319b  [malware]
# 2  malware--9ed10b5a-ff20-467f-bf2f-d3fbf763e381  [malware]
# 3  malware--3a913bac-4fae-4d0e-bca8-cae452f1599b  [malware]
#
#                    modified       name  \
# 0  2018-12-11T20:40:31.461Z       Judy
# 1  2018-12-11T20:40:31.461Z  SpyDealer
# 2  2018-12-11T20:40:31.461Z    RedDrop
# 3  2018-12-11T20:40:31.461Z  Skygofree
#
#                                  object_marking_refs     type x_mitre_aliases  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  malware          [Judy]
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  malware     [SpyDealer]
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  malware       [RedDrop]
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  malware     [Skygofree]
#
#   x_mitre_old_attack_id x_mitre_platforms x_mitre_version
# 0             MOB-S0041         [Android]             1.1
# 1             MOB-S0040         [Android]             1.1
# 2             MOB-S0042         [Android]             1.1
# 3             MOB-S0043         [Android]             1.1

# %% [markdown]
# **Mobile Tools**

# %%
print("Number of Tools in Mobile ATT&CK")
print(len(all_mobile['tools']))
# Out:
# Number of Tools in Mobile ATT&CK
# 1

# %%
tools = []
for t in all_mobile['tools']:
    tools.append(json.loads(t.serialize()))
df = json_normalize(tools)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2017-10-25T14:48:48.609Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [Xbot](https://attack.mitre.org/software/S0298...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/software/S0...
#
#                                            id  labels  \
# 0  tool--da21929e-40c0-443d-bdf4-6b60d15448b4  [tool]
#
#                    modified  name  \
# 0  2018-12-11T20:40:31.461Z  Xbot
#
#                                  object_marking_refs  type x_mitre_aliases  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  tool          [Xbot]
#
#   x_mitre_old_attack_id x_mitre_platforms x_mitre_version
# 0             MOB-S0014         [Android]             1.1

# %% [markdown]
# **Mobile Relationships**

# %%
print("Number of Relationships in Mobile ATT&CK")
print(len(all_mobile['relationships']))
# Out:
# Number of Relationships in Mobile ATT&CK
# 301

# %%
relations = []
for t in all_mobile['relationships']:
    relations.append(json.loads(t.serialize()))
df = json_normalize(relations)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-29T19:35:31.074Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-03-11T15:13:40.454Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-03-11T15:13:40.425Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-03-11T15:13:40.408Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0                                                NaN
# 1  [ANDROIDOS_ANSERVER.A](https://attack.mitre.or...
# 2  [ANDROIDOS_ANSERVER.A](https://attack.mitre.or...
# 3  \n[ANDROIDOS_ANSERVER.A](https://attack.mitre....
#
#                                  external_references  \
# 0                                                NaN
# 1  [{'url': 'http://blog.trendmicro.com/trendlabs...
# 2  [{'url': 'https://www.trendmicro.com/vinfo/us/...
# 3  [{'url': 'https://www.trendmicro.com/vinfo/us/...
#
#                                                   id  \
# 0  relationship--6186ed87-69a1-43e7-bb60-76527d28...
# 1  relationship--352fabc8-48fe-4190-92b3-49b00348...
# 2  relationship--a82d3cfb-7ef2-4e39-a6e1-3097d7b1...
# 3  relationship--919a13bc-74be-4660-af63-454abee9...
#
#                    modified  \
# 0  2019-04-29T19:35:31.074Z
# 1  2019-03-11T15:13:40.454Z
# 2  2019-03-11T15:13:40.425Z
# 3  2019-03-11T15:13:40.408Z
#
#                                  object_marking_refs relationship_type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...        revoked-by
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
#
#                                           source_ref  \
# 0  attack-pattern--0bcc4ec1-a897-49a9-a9ff-c00df1...
# 1      malware--4bf6ba32-4165-42c1-b911-9c36165891c8
# 2      malware--4bf6ba32-4165-42c1-b911-9c36165891c8
# 3      malware--4bf6ba32-4165-42c1-b911-9c36165891c8
#
#                                           target_ref          type
# 0  attack-pattern--2d646840-f6f5-4619-a5a8-29c831...  relationship
# 1  attack-pattern--c6a146ae-9c63-4606-97ff-e261e7...  relationship
# 2  attack-pattern--e2ea7f6b-8d4f-49c3-819d-660530...  relationship
# 3  attack-pattern--dd818ea5-adf5-41c7-93b5-f3b839...  relationship

# %% [markdown]
# ## **Get STIX Object Types Directly from TAXII Server (Enterprise ATT&CK, Pre-ATT&CK & Mobile ATT&CK)**
# * In this section, we will query the ATT&CK TAXII Server directly in order to collect specific stix object types such as techniques, mitigations, groups, malware, tools and relationships from the Enterprise, PRE and Mobile Matrices.
# * There is no need to get all the stix objects available per each matrix unlike the first section of this notebook.

# %% [markdown]
# ### Get All Enterprise Techniques ONLY (TAXII)

# %%
print("Number of Techniques in Enterprise ATT&CK")
techniques = lift.get_all_enterprise_techniques()
print(len(techniques))
# Out:
# Number of Techniques in Enterprise ATT&CK
# 244

# %%
techniques_list = []
for t in techniques:
    techniques_list.append(json.loads(t.serialize()))
df = json_normalize(techniques_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-25T20:53:07.719Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-23T15:34:30.008Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-18T11:00:55.862Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-17T22:22:24.505Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  Adversaries may attempt to make payloads diffi...
# 1  Systemd services can be used to establish pers...
# 2  Adversaries may perform Endpoint Denial of Ser...
# 3  Adversaries may check for the presence of a vi...
#
#                                  external_references  \
# 0  [{'external_id': 'T1500', 'source_name': 'mitr...
# 1  [{'external_id': 'T1501', 'source_name': 'mitr...
# 2  [{'external_id': 'T1499', 'source_name': 'mitr...
# 3  [{'external_id': 'T1497', 'source_name': 'mitr...
#
#                                                   id  \
# 0  attack-pattern--cf7b3a06-8b42-4c33-bbe9-012120...
# 1  attack-pattern--0fff2797-19cb-41ea-a5f1-8a9303...
# 2  attack-pattern--c675646d-e204-4aa8-978d-e3d6d6...
# 3  attack-pattern--82caa33e-d11a-433a-94ea-9b5a5f...
#
#                                    kill_chain_phases  \
# 0  [{'phase_name': 'defense-evasion', 'kill_chain...
# 1  [{'phase_name': 'persistence', 'kill_chain_nam...
# 2  [{'phase_name': 'impact', 'kill_chain_name': '...
# 3  [{'phase_name': 'defense-evasion', 'kill_chain...
#
#                    modified                            name  \
# 0  2019-04-29T21:13:49.686Z          Compile After Delivery
# 1  2019-04-29T14:14:08.450Z                 Systemd Service
# 2  2019-04-29T13:20:36.795Z      Endpoint Denial of Service
# 3  2019-04-29T14:17:25.403Z  Virtualization/Sandbox Evasion
#
#                                  object_marking_refs            type  ...  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern  ...
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern  ...
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern  ...
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern  ...
#
#                             x_mitre_defense_bypassed  \
# 0  [Static File Analysis, Binary Analysis, Anti-v...
# 1                                                NaN
# 2                                                NaN
# 3  [Anti-virus, Host forensic analysis, Signature...
#
#                                    x_mitre_detection  \
# 0  Monitor the execution file paths and command-l...
# 1  Systemd service unit files may be detected by ...
# 2  Detection of Endpoint DoS can sometimes be ach...
# 3  Virtualization, sandbox, and related discovery...
#
#   x_mitre_effective_permissions x_mitre_impact_type  \
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2                           NaN      [Availability]
# 3                           NaN                 NaN
#
#   x_mitre_network_requirements x_mitre_permissions_required  \
# 0                          NaN                       [User]
# 1                          NaN                 [root, User]
# 2                          NaN                          NaN
# 3                          NaN                          NaN
#
#          x_mitre_platforms x_mitre_remote_support  \
# 0  [Linux, macOS, Windows]                    NaN
# 1                  [Linux]                    NaN
# 2  [Linux, macOS, Windows]                    NaN
# 3                [Windows]                    NaN
#
#                          x_mitre_system_requirements x_mitre_version
# 0  [Compiler software (either native to the syste...             1.0
# 1                                                NaN             1.0
# 2                                                NaN             1.0
# 3                                                NaN             1.0
#
# [4 rows x 22 columns]

# %% [markdown]
# ### Get All PRE Techniques ONLY (TAXII)

# %%
print("Number of Techniques in PRE-ATT&CK")
techniques = lift.get_all_pre_techniques()
print(len(techniques))
# Out:
# Number of Techniques in PRE-ATT&CK
# 174

# %%
techniques_list = []
for t in techniques:
    techniques_list.append(json.loads(t.serialize()))
df = json_normalize(techniques_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2018-04-18T17:59:24.739Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2017-12-14T16:46:06.044Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2017-12-14T16:46:06.044Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2017-12-14T16:46:06.044Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  Spearphishing for information is a specific va...
# 1  A wide variety of cloud, virtual private servi...
# 2  Code signing is the process of digitally signi...
# 3  An adversary will assess collected information...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/techniques/...
# 1  [{'url': 'https://attack.mitre.org/techniques/...
# 2  [{'url': 'https://attack.mitre.org/techniques/...
# 3  [{'url': 'https://attack.mitre.org/techniques/...
#
#                                                   id  \
# 0  attack-pattern--b182f29c-2505-4b32-a000-0440ef...
# 1  attack-pattern--795c1a92-3a26-453e-b99a-6a566a...
# 2  attack-pattern--03f4a766-7a21-4b5e-9ccf-e0cf42...
# 3  attack-pattern--773950e1-090c-488b-a480-9ff236...
#
#                                    kill_chain_phases  \
# 0  [{'phase_name': 'technical-information-gatheri...
# 1  [{'phase_name': 'establish-&-maintain-infrastr...
# 2  [{'phase_name': 'establish-&-maintain-infrastr...
# 3  [{'phase_name': 'technical-weakness-identifica...
#
#                    modified  \
# 0  2018-10-17T00:14:20.652Z
# 1  2018-10-17T00:14:20.652Z
# 2  2019-02-19T18:56:56.071Z
# 3  2018-10-17T00:14:20.652Z
#
#                                                 name  \
# 0                      Spearphishing for Information
# 1  Acquire and/or use 3rd party infrastructure se...
# 2  Acquire or compromise 3rd party signing certif...
# 3                             Analyze data collected
#
#                                  object_marking_refs            type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  attack-pattern
#
#   x_mitre_deprecated x_mitre_detectable_by_common_defenses  \
# 0                NaN                               Partial
# 1                NaN                                    No
# 2                NaN                                    No
# 3                NaN                                    No
#
#    x_mitre_detectable_by_common_defenses_explanation  \
# 0  Depending on the specific method of phishing, ...
# 1  Hard to differentiate from standard business o...
# 2  Defender will not know what certificates an ad...
# 3  This can be done offline after the data has be...
#
#   x_mitre_difficulty_for_adversary  \
# 0                              Yes
# 1                              Yes
# 2                               No
# 3                              Yes
#
#         x_mitre_difficulty_for_adversary_explanation x_mitre_old_attack_id  \
# 0  Sending emails is trivial, and, over time, an ...             PRE-T1174
# 1  Wide variety of cloud/VPS/hosting/compute/stor...             PRE-T1106
# 2  It is trivial to purchase code signing certifi...             PRE-T1109
# 3  Many of the common tools highlight these weakn...             PRE-T1064
#
#   x_mitre_version
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0

# %% [markdown]
# ### Get All Mobile Techniques ONLY (TAXII)

# %%
print("Number of Techniques in Mobile ATT&CK")
techniques = lift.get_all_mobile_techniques()
print(len(techniques))
# Out:
# Number of Techniques in Mobile ATT&CK
# 82

# %%
techniques_list = []
for t in techniques:
    techniques_list.append(json.loads(t.serialize()))
df = json_normalize(techniques_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-02-01T17:29:43.503Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2018-10-17T00:14:20.652Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2018-10-17T00:14:20.652Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2018-10-17T00:14:20.652Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  Adversaries may use an existing, legitimate ex...
# 1  Malicious applications are a common attack vec...
# 2  As further described in [Supply Chain Compromi...
# 3  Malicious applications are a common attack vec...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/techniques/...
# 1  [{'url': 'https://attack.mitre.org/techniques/...
# 2  [{'url': 'https://attack.mitre.org/techniques/...
# 3  [{'url': 'https://attack.mitre.org/techniques/...
#
#                                                   id  \
# 0  attack-pattern--c6a146ae-9c63-4606-97ff-e261e7...
# 1  attack-pattern--d9db3d46-66ca-44b4-9daa-1ef97c...
# 2  attack-pattern--0d95940f-9583-4e0f-824c-a42c1b...
# 3  attack-pattern--53263a67-075e-48fa-974b-91c5b5...
#
#                                    kill_chain_phases  \
# 0  [{'phase_name': 'command-and-control', 'kill_c...
# 1  [{'phase_name': 'initial-access', 'kill_chain_...
# 2  [{'phase_name': 'initial-access', 'kill_chain_...
# 3  [{'phase_name': 'initial-access', 'kill_chain_...
#
#                    modified                                            name  \
# 0  2019-02-01T17:29:43.503Z                                     Web Service
# 1  2019-02-03T17:31:51.215Z  Deliver Malicious App via Authorized App Store
# 2  2018-10-17T00:14:20.652Z                         Supply Chain Compromise
# 3  2019-02-03T14:08:44.916Z           Deliver Malicious App via Other Means
#
#                                  object_marking_refs revoked            type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  attack-pattern
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  attack-pattern
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  attack-pattern
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  attack-pattern
#
#                                    x_mitre_detection x_mitre_old_attack_id  \
# 0                                                NaN                   NaN
# 1  * An EMM/MDM or mobile threat defense solution...             MOB-T1078
# 2  * Insecure third-party libraries could be dete...             MOB-T1077
# 3  * An EMM/MDM or mobile threat defense solution...             MOB-T1079
#
#   x_mitre_platforms             x_mitre_tactic_type x_mitre_version
# 0    [Android, iOS]  [Post-Adversary Device Access]             1.0
# 1    [Android, iOS]  [Post-Adversary Device Access]             1.0
# 2    [Android, iOS]  [Post-Adversary Device Access]             1.0
# 3    [Android, iOS]  [Post-Adversary Device Access]             1.1

# %% [markdown]
# ### Get All Techniques (TAXII)
# * The results of this function shows every single technique across the whole ATT&CK framework without their mitigations information
# * Mitigations information has its own stix object type (Mitigation) that needs to be correlated with the help of relationship properties
# * There is a function already created in this library named **get_all_techniques_with_mitigations()** that allows you to get a more complete view of techniques

# %%
print("Number of Techniques in ATT&CK")
techniques = lift.get_all_techniques()
print(len(techniques))
# Out:
# Number of Techniques in ATT&CK
# 500

# %%
techniques_list = []
for t in techniques:
    techniques_list.append(json.loads(t.serialize()))
df = json_normalize(techniques_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-25T20:53:07.719Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-23T15:34:30.008Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-18T11:00:55.862Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-17T22:22:24.505Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  Adversaries may attempt to make payloads diffi...
# 1  Systemd services can be used to establish pers...
# 2  Adversaries may perform Endpoint Denial of Ser...
# 3  Adversaries may check for the presence of a vi...
#
#                                  external_references  \
# 0  [{'external_id': 'T1500', 'source_name': 'mitr...
# 1  [{'external_id': 'T1501', 'source_name': 'mitr...
# 2  [{'external_id': 'T1499', 'source_name': 'mitr...
# 3  [{'external_id': 'T1497', 'source_name': 'mitr...
#
#                                                   id  \
# 0  attack-pattern--cf7b3a06-8b42-4c33-bbe9-012120...
# 1  attack-pattern--0fff2797-19cb-41ea-a5f1-8a9303...
# 2  attack-pattern--c675646d-e204-4aa8-978d-e3d6d6...
# 3  attack-pattern--82caa33e-d11a-433a-94ea-9b5a5f...
#
#                                    kill_chain_phases  \
# 0  [{'phase_name': 'defense-evasion', 'kill_chain...
# 1  [{'phase_name': 'persistence', 'kill_chain_nam...
# 2  [{'phase_name': 'impact', 'kill_chain_name': '...
# 3  [{'phase_name': 'defense-evasion', 'kill_chain...
#
#                    modified                            name  \
# 0  2019-04-29T21:13:49.686Z          Compile After Delivery
# 1  2019-04-29T14:14:08.450Z                 Systemd Service
# 2  2019-04-29T13:20:36.795Z      Endpoint Denial of Service
# 3  2019-04-29T14:17:25.403Z  Virtualization/Sandbox Evasion
#
#                                  object_marking_refs revoked  ...  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  ...
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  ...
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  ...
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  ...
#
#   x_mitre_effective_permissions x_mitre_impact_type  \
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2                           NaN      [Availability]
# 3                           NaN                 NaN
#
#   x_mitre_network_requirements x_mitre_old_attack_id  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# 2                          NaN                   NaN
# 3                          NaN                   NaN
#
#   x_mitre_permissions_required        x_mitre_platforms  \
# 0                       [User]  [Linux, macOS, Windows]
# 1                 [root, User]                  [Linux]
# 2                          NaN  [Linux, macOS, Windows]
# 3                          NaN                [Windows]
#
#   x_mitre_remote_support                        x_mitre_system_requirements  \
# 0                    NaN  [Compiler software (either native to the syste...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
#
#   x_mitre_tactic_type x_mitre_version
# 0                 NaN             1.0
# 1                 NaN             1.0
# 2                 NaN             1.0
# 3                 NaN             1.0
#
# [4 rows x 30 columns]

# %% [markdown]
# ### Get All Enterprise Mitigations ONLY (TAXII)

# %%
print("Number of Mitigations in Enterprise ATT&CK")
mitigations = lift.get_all_enterprise_mitigations()
print(len(mitigations))
# Out:
# Number of Mitigations in Enterprise ATT&CK
# 241

# %%
mitigations_list = []
for t in mitigations:
    mitigations_list.append(json.loads(t.serialize()))
df = json_normalize(mitigations_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-26T19:30:33.607Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-25T20:53:07.814Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-24T17:03:39.689Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-24T17:02:25.107Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  Prevent adversary access to privileged account...
# 1  This type of technique cannot be easily mitiga...
# 2  Identify critical business and system processe...
# 3  Identify critical business and system processe...
#
#                                  external_references  \
# 0  [{'external_id': 'T1495', 'source_name': 'mitr...
# 1  [{'external_id': 'T1502', 'source_name': 'mitr...
# 2  [{'external_id': 'T1493', 'source_name': 'mitr...
# 3  [{'external_id': 'T1492', 'source_name': 'mitr...
#
#                                                   id  \
# 0  course-of-action--70886857-0f19-4caa-b081-5483...
# 1  course-of-action--ae56a49d-5281-45c5-ab95-70a1...
# 2  course-of-action--245075bc-f992-4d89-af8c-834c...
# 3  course-of-action--e9362d25-4427-446b-99e8-b8f0...
#
#                    modified                                      name  \
# 0  2019-04-26T19:41:45.126Z            Firmware Corruption Mitigation
# 1  2019-04-26T14:19:09.167Z         Compile After Delivery Mitigation
# 2  2019-04-26T18:48:27.528Z  Transmitted Data Manipulation Mitigation
# 3  2019-04-26T18:57:01.963Z       Stored Data Manipulation Mitigation
#
#                                  object_marking_refs              type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
#
#   x_mitre_version
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0

# %% [markdown]
# ### Get All Mobile Mitigations ONLY (TAXII)

# %%
print("Number of Mitigations in Mobile ATT&CK")
mitigations = lift.get_all_mobile_mitigations()
print(len(mitigations))
# Out:
# Number of Mitigations in Mobile ATT&CK
# 14

# %%
mitigations_list = []
for t in mitigations:
    mitigations_list.append(json.loads(t.serialize()))
df = json_normalize(mitigations_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2017-10-25T14:48:53.732Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2017-10-25T14:48:53.318Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2017-10-25T14:48:52.933Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2017-10-25T14:48:52.601Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  This mitigation describes any guidance or trai...
# 1  An enterprise mobility management (EMM), also ...
# 2  Enable remote attestation capabilities when av...
# 3  A variety of methods exist that can be used to...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/mitigations...
# 1  [{'url': 'https://attack.mitre.org/mitigations...
# 2  [{'url': 'https://attack.mitre.org/mitigations...
# 3  [{'url': 'https://attack.mitre.org/mitigations...
#
#                                                   id  \
# 0  course-of-action--25dc1ce8-eb55-4333-ae30-a7cb...
# 1  course-of-action--649f7268-4c12-483b-ac84-4b7b...
# 2  course-of-action--ff4821f6-5afb-481b-8c0f-26c2...
# 3  course-of-action--cf2cccb1-cab8-431a-8ecf-f787...
#
#                    modified                                        name  \
# 0  2018-10-17T00:14:20.652Z              Application Developer Guidance
# 1  2018-10-17T00:14:20.652Z                           Enterprise Policy
# 2  2018-10-17T00:14:20.652Z                                 Attestation
# 3  2018-10-17T00:14:20.652Z  Deploy Compromised Device Detection Method
#
#                                  object_marking_refs              type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
#
#   x_mitre_old_attack_id x_mitre_version
# 0             MOB-M1013             1.0
# 1             MOB-M1012             1.0
# 2             MOB-M1002             1.0
# 3             MOB-M1010             1.0

# %% [markdown]
# ### Get All Mitigations (TAXII)

# %%
print("Number of Mitigations in ATT&CK")
mitigations = lift.get_all_mitigations()
print(len(mitigations))
# Out:
# Number of Mitigations in ATT&CK
# 255

# %%
mitigations_list = []
for t in mitigations:
    mitigations_list.append(json.loads(t.serialize()))
df = json_normalize(mitigations_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-26T19:30:33.607Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-25T20:53:07.814Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-24T17:03:39.689Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-24T17:02:25.107Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  Prevent adversary access to privileged account...
# 1  This type of technique cannot be easily mitiga...
# 2  Identify critical business and system processe...
# 3  Identify critical business and system processe...
#
#                                  external_references  \
# 0  [{'external_id': 'T1495', 'source_name': 'mitr...
# 1  [{'external_id': 'T1502', 'source_name': 'mitr...
# 2  [{'external_id': 'T1493', 'source_name': 'mitr...
# 3  [{'external_id': 'T1492', 'source_name': 'mitr...
#
#                                                   id  \
# 0  course-of-action--70886857-0f19-4caa-b081-5483...
# 1  course-of-action--ae56a49d-5281-45c5-ab95-70a1...
# 2  course-of-action--245075bc-f992-4d89-af8c-834c...
# 3  course-of-action--e9362d25-4427-446b-99e8-b8f0...
#
#                    modified                                      name  \
# 0  2019-04-26T19:41:45.126Z            Firmware Corruption Mitigation
# 1  2019-04-26T14:19:09.167Z         Compile After Delivery Mitigation
# 2  2019-04-26T18:48:27.528Z  Transmitted Data Manipulation Mitigation
# 3  2019-04-26T18:57:01.963Z       Stored Data Manipulation Mitigation
#
#                                  object_marking_refs              type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  course-of-action
#
#   x_mitre_old_attack_id x_mitre_version
# 0                   NaN             1.0
# 1                   NaN             1.0
# 2                   NaN             1.0
# 3                   NaN             1.0

# %% [markdown]
# ### Get All Enterprise Groups ONLY (TAXII)

# %%
print("Number of Groups in Enterprise ATT&CK")
groups = lift.get_all_enterprise_groups()
print(len(groups))
# Out:
# Number of Groups in Enterprise ATT&CK
# 88

# %% [markdown]
# ### Get All PRE Groups ONLY (TAXII)

# %%
print("Number of Groups in PRE-ATT&CK")
groups = lift.get_all_pre_groups()
print(len(groups))
# Out:
# Number of Groups in PRE-ATT&CK
# 7

# %%
groups_list = []
for t in groups:
    groups_list.append(json.loads(t.serialize()))
df = json_normalize(groups_list)
df[0:4]
# Out:
#                   aliases                   created  \
# 0  [TEMP.Veles, XENOTIME]  2019-04-16T15:14:38.533Z
# 1     [APT17, Deputy Dog]  2017-05-31T21:31:57.307Z
# 2                 [APT16]  2017-05-31T21:31:56.270Z
# 3          [Night Dragon]  2017-05-31T21:31:51.643Z
#
#                                    created_by_ref  \
# 0  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [TEMP.Veles](https://attack.mitre.org/groups/G...
# 1  [APT17](https://attack.mitre.org/groups/G0025)...
# 2  [APT16](https://attack.mitre.org/groups/G0023)...
# 3  [Night Dragon](https://attack.mitre.org/groups...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/groups/G008...
# 1  [{'url': 'https://attack.mitre.org/groups/G002...
# 2  [{'url': 'https://attack.mitre.org/groups/G002...
# 3  [{'url': 'https://attack.mitre.org/groups/G001...
#
#                                                   id  \
# 0  intrusion-set--9538b1a4-4120-4e2d-bf59-3b11fca...
# 1  intrusion-set--090242d7-73fc-4738-af68-20162f7...
# 2  intrusion-set--d6e88e18-81e8-4709-82d8-973095d...
# 3  intrusion-set--23b6a0f5-fa95-46f9-a6f3-4549c5e...
#
#                    modified          name  \
# 0  2019-04-29T18:59:16.079Z    TEMP.Veles
# 1  2019-03-22T14:21:19.419Z         APT17
# 2  2019-03-22T14:20:45.561Z         APT16
# 3  2019-03-25T14:36:29.638Z  Night Dragon
#
#                                  object_marking_refs           type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  intrusion-set
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...  intrusion-set
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...  intrusion-set
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...  intrusion-set
#
#   x_mitre_contributors x_mitre_version
# 0                  NaN             1.0
# 1                  NaN             1.0
# 2                  NaN             1.0
# 3                  NaN             1.1

# %% [markdown]
# ### Get All Mobile Groups ONLY (TAXII)

# %%
print("Number of Groups in Mobile ATT&CK")
groups = lift.get_all_mobile_groups()
print(len(groups))
# Out:
# Number of Groups in Mobile ATT&CK
# 1

# %%
groups_list = []
for t in groups:
    groups_list.append(json.loads(t.serialize()))
df = json_normalize(groups_list)
df[0:4]
# Out:
#                                              aliases  \
# 0  [APT28, SNAKEMACKEREL, Swallowtail, Group 74, ...
#
#                     created                                  created_by_ref  \
# 0  2017-05-31T21:31:48.664Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [APT28](https://attack.mitre.org/groups/G0007)...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/groups/G000...
#
#                                                   id  \
# 0  intrusion-set--bef4c620-0787-42a8-a96d-b7eb6e8...
#
#                    modified   name  \
# 0  2019-04-29T18:16:13.040Z  APT28
#
#                                  object_marking_refs           type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...  intrusion-set
#
#                                 x_mitre_contributors x_mitre_version
# 0  [Emily Ratliff, IBM, Richard Gold, Digital Sha...             2.0

# %% [markdown]
# ### Get All Groups (TAXII)

# %% [markdown]
# * This function gathers all groups defined in each Matrix (Enterprise, PRE & Mobile) and returns the unique ones
#   * This is because groups can be repeated across matrices

# %%
print("Number of Groups in ATT&CK")
groups = lift.get_all_groups()
print(len(groups))
# Out:
# Number of Groups in ATT&CK
# 88

# %%
groups_list = []
for t in groups:
    groups_list.append(json.loads(t.serialize()))
df = json_normalize(groups_list)
df[0:4]
# Out:
#                   aliases                   created  \
# 0  [TEMP.Veles, XENOTIME]  2019-04-16T15:14:38.533Z
# 1         [APT39, Chafer]  2019-02-19T16:01:38.585Z
# 2         [Stolen Pencil]  2019-02-05T17:56:55.233Z
# 3                  [FIN4]  2019-01-31T02:01:45.129Z
#
#                                    created_by_ref  \
# 0  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [TEMP.Veles](https://attack.mitre.org/groups/G...
# 1  [APT39](https://attack.mitre.org/groups/G0087)...
# 2  [Stolen Pencil](https://attack.mitre.org/group...
# 3  [FIN4](https://attack.mitre.org/groups/G0085) ...
#
#                                  external_references  \
# 0  [{'url': 'https://attack.mitre.org/groups/G008...
# 1  [{'external_id': 'G0087', 'source_name': 'mitr...
# 2  [{'external_id': 'G0086', 'source_name': 'mitr...
# 3  [{'url': 'https://attack.mitre.org/groups/G008...
#
#                                                   id  \
# 0  intrusion-set--9538b1a4-4120-4e2d-bf59-3b11fca...
# 1  intrusion-set--44e43fad-ffcb-4210-abcf-eaaed97...
# 2  intrusion-set--7a0d4c09-dfe7-4fa2-965a-1a0e42f...
# 3  intrusion-set--d0b3393b-3bec-4ba3-bda9-199d30d...
#
#                    modified           name  \
# 0  2019-04-29T18:59:16.079Z     TEMP.Veles
# 1  2019-04-29T18:16:38.235Z          APT39
# 2  2019-04-19T18:38:31.839Z  Stolen Pencil
# 3  2019-04-18T20:19:49.089Z           FIN4
#
#                                  object_marking_refs revoked           type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  intrusion-set
#
#   x_mitre_contributors x_mitre_version
# 0                  NaN             1.0
# 1                  NaN             2.0
# 2                  NaN             1.0
# 3                  NaN             1.0

# %% [markdown]
# ### Get All Enterprise & Mobile Software (Malware & Tools) (TAXII)

# %%
print("Number of Software in ATT&CK")
software = lift.get_all_software()
print(len(software))
# Out:
# Number of Software in ATT&CK
# 378

# %% [markdown]
# ### Get All Enterprise Relationships ONLY (TAXII)

# %%
software_list = []
for t in software:
    software_list.append(json.loads(t.serialize()))
df = json_normalize(software_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-23T12:31:58.125Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-03-25T12:30:40.919Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-03-11T14:13:40.648Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-02-19T19:17:14.971Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [PoshC2](https://attack.mitre.org/software/S03...
# 1  [RawDisk](https://attack.mitre.org/software/S0...
# 2  [Empire](https://attack.mitre.org/software/S03...
# 3  [Expand](https://attack.mitre.org/software/S03...
#
#                                  external_references  \
# 0  [{'external_id': 'S0378', 'source_name': 'mitr...
# 1  [{'external_id': 'S0364', 'source_name': 'mitr...
# 2  [{'url': 'https://attack.mitre.org/software/S0...
# 3  [{'external_id': 'S0361', 'source_name': 'mitr...
#
#                                            id  labels  \
# 0  tool--4b57c098-f043-4da2-83ef-7588a6d426bc  [tool]
# 1  tool--3ffbdc1f-d2bf-41ab-91a2-c7b857e98079  [tool]
# 2  tool--3433a9e8-1c47-4320-b9bf-ed449061d1c3  [tool]
# 3  tool--ca656c25-44f1-471b-9d9f-e2a3bbb84973  [tool]
#
#                    modified     name  \
# 0  2019-04-23T18:29:12.005Z   PoshC2
# 1  2019-04-19T19:04:55.892Z  RawDisk
# 2  2019-04-24T20:24:34.115Z   Empire
# 3  2019-04-19T18:52:30.033Z   Expand
#
#                                  object_marking_refs revoked  type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  tool
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  tool
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  tool
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...     NaN  tool
#
#                        x_mitre_aliases             x_mitre_contributors  \
# 0                             [PoshC2]                              NaN
# 1                            [RawDisk]                              NaN
# 2  [Empire, EmPyre, PowerShell Empire]                              NaN
# 3                             [Expand]  [Matthew Demaske, Adaptforward]
#
#   x_mitre_old_attack_id        x_mitre_platforms x_mitre_version
# 0                   NaN  [Windows, Linux, macOS]             1.0
# 1                   NaN                [Windows]             1.0
# 2                   NaN  [Linux, macOS, Windows]             1.0
# 3                   NaN                [Windows]             1.0

# %%
print("Number of Relationships in Enterprise ATT&CK")
relationships = lift.get_all_enterprise_relationships()
print(len(relationships))
# Out:
# Number of Relationships in Enterprise ATT&CK
# 4852

# %%
relations_list = []
for t in relationships:
    relations_list.append(json.loads(t.serialize()))
df = json_normalize(relations_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-29T15:54:23.241Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-29T15:53:48.468Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-26T20:07:36.100Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-26T19:30:33.727Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0                                                NaN
# 1  [APT39](https://attack.mitre.org/groups/G0087)...
# 2  [Ebury](https://attack.mitre.org/software/S037...
# 3                                                NaN
#
#                                  external_references  \
# 0  [{'url': 'https://www.symantec.com/connect/blo...
# 1  [{'url': 'https://www.symantec.com/connect/blo...
# 2  [{'url': 'https://www.welivesecurity.com/2014/...
# 3                                                NaN
#
#                                                   id  \
# 0  relationship--2a37ddb3-56ef-4c2d-bec7-d6060eb0...
# 1  relationship--439344c5-67e0-4d38-9b91-866392e5...
# 2  relationship--9af6241d-355a-4673-b772-8384a718...
# 3  relationship--dfd5d379-9af4-4234-a0b2-a1591197...
#
#                    modified  \
# 0  2019-04-29T18:16:38.854Z
# 1  2019-04-29T18:16:38.727Z
# 2  2019-04-26T20:14:18.255Z
# 3  2019-04-26T19:30:33.727Z
#
#                                  object_marking_refs relationship_type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...         mitigates
#
#                                           source_ref  \
# 0  intrusion-set--44e43fad-ffcb-4210-abcf-eaaed97...
# 1  intrusion-set--44e43fad-ffcb-4210-abcf-eaaed97...
# 2      malware--d6b3fcd0-1c86-4350-96f0-965ed02fcc51
# 3  course-of-action--70886857-0f19-4caa-b081-5483...
#
#                                           target_ref          type
# 0      malware--ecc2f65a-b452-4eaf-9689-7e181f17f7a5  relationship
# 1  attack-pattern--03d7999c-1f4c-42cc-8373-e7690d...  relationship
# 2  attack-pattern--b3d682b6-98f2-4fb0-aa3b-b4df00...  relationship
# 3  attack-pattern--f5bb433e-bdf6-4781-84bc-35e97e...  relationship

# %% [markdown]
# ### Get All PRE Relationships ONLY (TAXII)

# %%
print("Number of Relationships in PRE-ATT&CK")
relationships = lift.get_all_pre_relationships()
print(len(relationships))
# Out:
# Number of Relationships in PRE-ATT&CK
# 70

# %%
relations_list = []
for t in relationships:
    relations_list.append(json.loads(t.serialize()))
df = json_normalize(relations_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-24T19:45:44.212Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-24T19:45:44.205Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-02-19T18:56:56.770Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-02-19T18:56:56.136Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0  [TEMP.Veles](https://attack.mitre.org/groups/G...
# 1  [TEMP.Veles](https://attack.mitre.org/groups/G...
# 2                                                NaN
# 3                                                NaN
#
#                                  external_references  \
# 0  [{'url': 'https://www.fireeye.com/blog/threat-...
# 1  [{'url': 'https://www.fireeye.com/blog/threat-...
# 2                                                NaN
# 3                                                NaN
#
#                                                   id  \
# 0  relationship--21842707-0f15-43bf-bc42-2bceadf2...
# 1  relationship--2d95ed6f-52e7-4708-af15-9a6c0839...
# 2  relationship--83379e43-4bc5-4c49-b0b3-f41161e8...
# 3  relationship--1aafdefb-304e-4998-87cc-81aad295...
#
#                    modified  \
# 0  2019-04-29T18:59:16.596Z
# 1  2019-04-29T18:59:16.595Z
# 2  2019-02-19T18:56:56.770Z
# 3  2019-02-19T18:56:56.136Z
#
#                                  object_marking_refs relationship_type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...        related-to
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...        related-to
#
#                                           source_ref  \
# 0  intrusion-set--9538b1a4-4120-4e2d-bf59-3b11fca...
# 1  intrusion-set--9538b1a4-4120-4e2d-bf59-3b11fca...
# 2  attack-pattern--e5164428-03ca-4336-a9a7-4d9ea1...
# 3  attack-pattern--03f4a766-7a21-4b5e-9ccf-e0cf42...
#
#                                           target_ref          type
# 0  attack-pattern--20a66013-8dab-4ca3-a67d-766c84...  relationship
# 1  attack-pattern--795c1a92-3a26-453e-b99a-6a566a...  relationship
# 2  attack-pattern--03f4a766-7a21-4b5e-9ccf-e0cf42...  relationship
# 3  attack-pattern--e5164428-03ca-4336-a9a7-4d9ea1...  relationship

# %% [markdown]
# ### Get All Mobile Relationships ONLY (TAXII)

# %%
print("Number of Relationships in Mobile ATT&CK")
relationships = lift.get_all_mobile_relationships()
print(len(relationships))
# Out:
# Number of Relationships in Mobile ATT&CK
# 301

# %%
relations_list = []
for t in relationships:
    relations_list.append(json.loads(t.serialize()))
df = json_normalize(relations_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-29T19:35:31.074Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-03-11T15:13:40.454Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-03-11T15:13:40.425Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-03-11T15:13:40.408Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0                                                NaN
# 1  [ANDROIDOS_ANSERVER.A](https://attack.mitre.or...
# 2  [ANDROIDOS_ANSERVER.A](https://attack.mitre.or...
# 3  \n[ANDROIDOS_ANSERVER.A](https://attack.mitre....
#
#                                  external_references  \
# 0                                                NaN
# 1  [{'url': 'http://blog.trendmicro.com/trendlabs...
# 2  [{'url': 'https://www.trendmicro.com/vinfo/us/...
# 3  [{'url': 'https://www.trendmicro.com/vinfo/us/...
#
#                                                   id  \
# 0  relationship--6186ed87-69a1-43e7-bb60-76527d28...
# 1  relationship--352fabc8-48fe-4190-92b3-49b00348...
# 2  relationship--a82d3cfb-7ef2-4e39-a6e1-3097d7b1...
# 3  relationship--919a13bc-74be-4660-af63-454abee9...
#
#                    modified  \
# 0  2019-04-29T19:35:31.074Z
# 1  2019-03-11T15:13:40.454Z
# 2  2019-03-11T15:13:40.425Z
# 3  2019-03-11T15:13:40.408Z
#
#                                  object_marking_refs relationship_type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...        revoked-by
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
#
#                                           source_ref  \
# 0  attack-pattern--0bcc4ec1-a897-49a9-a9ff-c00df1...
# 1      malware--4bf6ba32-4165-42c1-b911-9c36165891c8
# 2      malware--4bf6ba32-4165-42c1-b911-9c36165891c8
# 3      malware--4bf6ba32-4165-42c1-b911-9c36165891c8
#
#                                           target_ref          type
# 0  attack-pattern--2d646840-f6f5-4619-a5a8-29c831...  relationship
# 1  attack-pattern--c6a146ae-9c63-4606-97ff-e261e7...  relationship
# 2  attack-pattern--e2ea7f6b-8d4f-49c3-819d-660530...  relationship
# 3  attack-pattern--dd818ea5-adf5-41c7-93b5-f3b839...  relationship

# %% [markdown]
# ### Get All Relationships (TAXII)

# %%
print("Number of Relationships in ATT&CK")
relationships = lift.get_all_relationships()
print(len(relationships))
# Out:
# Number of Relationships in ATT&CK
# 5223

# %%
relations_list = []
for t in relationships:
    relations_list.append(json.loads(t.serialize()))
df = json_normalize(relations_list)
df[0:4]
# Out:
#                     created                                  created_by_ref  \
# 0  2019-04-29T15:54:23.241Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 1  2019-04-29T15:53:48.468Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 2  2019-04-26T20:07:36.100Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
# 3  2019-04-26T19:30:33.727Z  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5
#
#                                          description  \
# 0                                                NaN
# 1  [APT39](https://attack.mitre.org/groups/G0087)...
# 2  [Ebury](https://attack.mitre.org/software/S037...
# 3                                                NaN
#
#                                  external_references  \
# 0  [{'url': 'https://www.symantec.com/connect/blo...
# 1  [{'url': 'https://www.symantec.com/connect/blo...
# 2  [{'url': 'https://www.welivesecurity.com/2014/...
# 3                                                NaN
#
#                                                   id  \
# 0  relationship--2a37ddb3-56ef-4c2d-bec7-d6060eb0...
# 1  relationship--439344c5-67e0-4d38-9b91-866392e5...
# 2  relationship--9af6241d-355a-4673-b772-8384a718...
# 3  relationship--dfd5d379-9af4-4234-a0b2-a1591197...
#
#                    modified  \
# 0  2019-04-29T18:16:38.854Z
# 1  2019-04-29T18:16:38.727Z
# 2  2019-04-26T20:14:18.255Z
# 3  2019-04-26T19:30:33.727Z
#
#                                  object_marking_refs relationship_type  \
# 0  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 1  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 2  [marking-definition--fa42a846-8d90-4e51-bc29-7...              uses
# 3  [marking-definition--fa42a846-8d90-4e51-bc29-7...         mitigates
#
#                                           source_ref  \
# 0  intrusion-set--44e43fad-ffcb-4210-abcf-eaaed97...
# 1  intrusion-set--44e43fad-ffcb-4210-abcf-eaaed97...
# 2      malware--d6b3fcd0-1c86-4350-96f0-965ed02fcc51
# 3  course-of-action--70886857-0f19-4caa-b081-5483...
#
#                                           target_ref          type
# 0      malware--ecc2f65a-b452-4eaf-9689-7e181f17f7a5  relationship
# 1  attack-pattern--03d7999c-1f4c-42cc-8373-e7690d...  relationship
# 2  attack-pattern--b3d682b6-98f2-4fb0-aa3b-b4df00...  relationship
# 3  attack-pattern--f5bb433e-bdf6-4781-84bc-35e97e...  relationship
